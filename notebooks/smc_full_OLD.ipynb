# %%
''' Import required packages
'''

import sys
import time
import numpy as np
import matplotlib.pyplot as plt
import numba
import pandas as pd
import seaborn as sns
from matplotlib.animation import FuncAnimation
from scipy.stats import norm
from numba import njit, prange
from concurrent.futures import ProcessPoolExecutor
numba.config.FULL_TRACEBACKS = True

# %%
''' Sampling from the non-linear state-space model with
equations x_t+1 = atan(x_t) + theta_1 * u_t + v_t, v_t ~ N(0,1)
          y_t   = |x_t| + theta_1 * theta_2 + e_t, e_t ~ N(0,0.01).
True parameters used for sampling are not given explicitly in the
paper, so let us pick these ourselves: theta_1 = 1, theta_2 = 1.
'''

@njit
def g(x, theta):
    """ Deterministic part of the
    distribution ``p(y_t|x_t,theta)`` in the
    state-space model described above.
    
    Parameters
    -
    x              : float
                     Latent space variable
    theta          : ndarray of shape (2,)
                     Parameters for the state-space model
                     
    Returns
    -
    Deterministic part of observation
    """
    return np.abs(x) + theta[0] * theta[1]

@njit
def f(x, theta, u):
    """ Deterministic part of the
    distribution ``p(x_t|x_t-1,theta)`` in the
    state-space model described above.
    
    Parameters
    -
    x              : float
                     Previous latent-space state
    theta          : ndarray of shape (2,)
                     Parameters for the state-space model
    u              : float
                     Previous exogenous input parameter
    
    Returns
    -
    Deterministic part of next latent-space state
    """
    return np.atan(x) + theta[0] * u

    

def sample_state_space_model(us, T=200, theta=np.asarray([1,1]), rng=None):
    """Sample observations from the non-linear
    state-space model described in Svensson et al. (2017).

    Parameters
    -
    T     : int, default=500
            Number of time steps to simulate.
    theta : ndarray of shape (2,):
            Parameters of underlying state-space model.
    us    : ndarray of shape (T,):
            List of exogenous input variables.
    rng   : numpy rng object
            Random number generator to use for drawing samples,
            so that we can consistently look at the same
            observation sample for fair comparisons
            later down the line
          
    Returns
    -
    ys : ndarray of shape (T,)
        Simulated observations generated from the state space model.
    """
    
    # If no random generator is provided,
    # use the default.
    if rng is None:
        rng = np.random.default_rng()

    xs = np.zeros((T,)) # Storage for latent states
    ys = np.zeros((T,)) # Storage for observations
    xs[0] = 0 # Initial condition
    ys[0] = rng.normal(g(xs[0], theta),0.01)
    for i in range(1, T):
        # Evolve latent space according to formula
        # in Svensson et al. (2017).
        xs[i] = rng.normal(f(xs[i-1],theta,us[i-1]), 1)
        ys[i] = rng.normal(g(xs[i],theta),0.01)
    return ys

# %%
''' Draw sample paths from the state-space model defined above.
Do some quick visualization.
'''


n_paths = 3 # Number of paths to draw
T = 100 # Number of samples in each path

rng = np.random.default_rng(seed=42) # Want to fix this while keeping the rest random
us = rng.normal(loc=0, scale=1, size=T) # Fixed exogenous input variables

for _ in range(n_paths):
    ys = sample_state_space_model(us=us,T=T,theta=np.asarray([-1,0.8]),rng=rng)
    plt.plot(ys, alpha=0.7)

plt.title("Sample paths from state-space model")
plt.xlabel("Time")
plt.ylabel("Observation")
plt.show()

# %%
""" Implementation of the bootstrap particle filter
for this non-linear state-space model.
"""

@njit
def normal_logpdf(x, loc, scale):
    """ Compute log pdf of normal distribution
    with mean loc and variance scale.
    """
    return -0.5 * np.log(2*np.pi*scale) - 0.5 * (x - loc)**2 / scale

@njit
def logsumexp(x):
    """Fast numerically stable logsumexp
    """
    m = np.max(x)

    s = 0.0
    for i in range(len(x)):
        s += np.exp(x[i] - m)

    return m + np.log(s)


@njit
def multinomial_resample(weights):
    """Get resampled indices based on
    normalized weight vector.
    Fast njit-compatible version of
    multinomial resampling
    """
    N = len(weights)
    
    cdf = np.empty(N)

    cdf[0] = weights[0]

    for i in range(1, N):
        cdf[i] = cdf[i-1] + weights[i]

    out = np.empty(N, dtype=np.int64)

    for i in range(N):

        u = np.random.rand()
        out[i] = np.searchsorted(cdf, u)

    return out


@njit
def particle_filter(temp, n_particles, ys, us, theta, alternative_tempering=False):
    """ Bootstrap particle filter for the nonlinear
    state-space model defined above.
    
    Parameters
    -
    temp        : float
                  tempering parameter
    n_particles : int
                  number of particles to use
    ys          : ndarray of shape (T,)
                  List of observations from the 
                  underlying state-space model
    us          : ndarray of shape (T,)
                  List of exogenous input parameters
                  in the underlying state-space model
    theta       : ndarray of shape (2,)
                  Parameters of the underlying state-space
                  model
                  
    Returns
    -
    List of samples ``x_1:T`` of shape (n_particles,T) from the filtering
    distributions ``p(x_t|y_1:t,theta,temp)``, to be used
    in the approximation of the likelihood ``p(y_1:T|theta,temp)``
    
    List of internal resampling states ``a_2:T`` of shape (n_particlesT-1)

    Estimate of log-likelihood of the observations
    """
    
    # Ensure consistent shape for theta to make
    # numba work
    theta = np.asarray(theta).reshape(2,)
    
    T = len(ys) # Number of observations
    xs = np.zeros(shape=(n_particles,T)) # Particle storage
    aas = np.zeros(shape=(n_particles,T-1),dtype=np.int64) # Resampling storage
    
    # Baseline variance, only change if using the standard tempering scheme
    # (the one from Svensson et al.)
    var = 0.01
    if alternative_tempering == False:
        var += temp # Variance after tempering
    log_w = np.empty(n_particles) # Weight storage

    # Sample initial xs from ``p(x|theta)`` in the state-space model
    # Initial condition is just deterministically 0, so just set to 0
    xs[:,0] = np.zeros(n_particles)

    # Weight according to f(y_1|x_1,theta,temp) = N(|x_1| + theta1 * theta2, 0.01 + temp)
    # Recall: going from p(x|theta,temp) to p(x|y,theta,temp) = 
    # f(y|x,theta,temp)p(x|theta,temp) / p(y|theta,temp)
    # Recall: so up to x-proportionality, dQ(x)/dM(x) = f(y|x,theta,temp)    
    for i in range(n_particles):
        
        if alternative_tempering == False:
            log_w[i] = normal_logpdf(ys[0], loc=g(xs[i,0],theta), scale=var)
        else: # Alternatively, weigh according to f(y_1|x_1,theta,temp) = f(y_1|x_1,theta)^(1/temp)
            log_w[i] = normal_logpdf(ys[0], loc=g(xs[i,0],theta), scale=var) / temp
    
    # Iterate over timesteps
    lse = logsumexp(log_w) # Store logsumexp, use later
    log_lik = lse - np.log(n_particles) # Keep track of log-likelihood
    for t in range(1,T):

        # Normalize weights
        w_norm = np.exp(log_w - lse)
        
        # Resample indices according to the normalized weights
        aas[:,t-1] = multinomial_resample(w_norm)
        
        # Extend and reweight
        for i in range(n_particles):
            
            # Extend
            xs[i,t] = np.random.normal(
                                    loc=f(xs[aas[i,t-1],t-1],
                                    theta=theta,
                                    u=us[t-1]),
                                    scale=1)
            # Reweight
            if alternative_tempering == False:
                log_w[i] = normal_logpdf(ys[t], loc=g(xs[i,t],theta), scale=var)
            else: # Alternatively, weigh according to f(y_1|x_1,theta,temp) = f(y_1|x_1,theta)^(1/temp)
                log_w[i] = normal_logpdf(ys[t], loc=g(xs[i,t],theta), scale=var) / temp
        
        
        # Recall: likelihood is prod_t=1^T 1/N * sum_n=1^N g(y_t|x_t^n,temp)
        # So this can quickly be obtained from the PF by summing the
        # unnormalized weights
        lse = logsumexp(log_w) # Store logsumexp, reuse later
        log_lik += lse - np.log(n_particles) # Update log-likelihod

    return xs, aas, log_lik

# %%
""" Implementation of particle Metropolis-Hastings (PMH)
for this state-space model.
"""

@njit
def log_prior(theta):
    """Compute prior probability of observing
    parameter theta.
    
    Parameters
    -
    theta : ndarray of shape (2,)
            Parameter of state-space model
    """
    if 0 <= theta[0] <= 2 and 0 <= theta[1] <= 2:
        return 0.0
    else:
        return -np.inf

@njit
def sample_prior(n=1):
    """Sample from uniform prior
    on theta.
    
    Parameters
    -
    n : int
        Number of samples to draw
    """
    return np.random.uniform(0,2,size=(n,2))


@njit
def particle_metropolis_hastings(
    theta, 
    xs,
    aas,
    log_lik, 
    us,
    ys,
    temp,
    n_iters=1, 
    proposal_sd=0.01, 
    verbose=False,
    alternative_tempering=False
    ):
    """Draw samples from the posterior ``p(theta|y_1:T,temp)`` 
    of the tempered non-linear state space model described above,
    using a random-walk particle Metropolis-Hastings algorithm with 
    bivariate normal proposal.
    
    Parameters
    -
    theta         : ndarray of shape (2,)
                    Initial parameter value
    xs            : ndarray of shape (n_particles,T)
                    Particles used for sampling the initial
                    parameter value
    aas           : ndarray of shape (n_particles,T-1)
                    Internal resampling state of the particle
                    filter used for sampling the initial parameter
                    value
    log_lik       : np.float64
                    Log-likelihood obtained from the particle filter
                    used when sampling the initial parameter value
    temp          : float
                    Tempering parameter of the distribution to sample
                    from.
    ys            : ndarray of shape (T,)
                    List of observations on which the distribution to
                    sample from is conditioned.
    n_iters       : int, default=1
                    Number of iterations to run the Metropolis-Hastings
                    algorithm for.
    proposal_sd   : float, default=0.01
                    Standard deviation of the proposal distribution.
    verbose       : Boolean, default=False
                    Whether or not to print additional diagnostic information
                    while running the algorithm
                    
    Returns
    -
    thetas : ndarray of shape (n_iters,2)
             List of M-H parameter samples
    xss    : ndarray of shape (n_iters, n_particles,T)
             List of internal particles for estimation of M-H samples
    aass   : ndarray of shape (n_iters,n_particles,T-1)
             List of internal particle filter resampling states for
             estimation of M-H samples
    """
    T = len(ys) # Number of observations
    n_particles = xs.shape[0] # Number of particles
    n_accepts = 0 # Keep track of acceptance rate
    var = 0.01 + temp # Observation variance after tempering
    
    # Keep track of all samples, including the initial sample
    thetas = np.zeros(shape=(n_iters+1,2))
    thetas[0] = theta.flatten()

    log_liks = np.zeros(shape=(n_iters,)) # Keep track of sample log likelihoods
    
    # Keep track of all internal states, including the initial state
    xss = np.zeros(shape=(n_iters+1,n_particles,T))
    aass = np.zeros(shape=(n_iters+1,n_particles,T-1),dtype=np.int64)
    xss[0,:,:] = xs
    aass[0,:,:] = aas
     
    for i in range(1,n_iters+1):
        
        # Propose new parameter according to a
        # random walk proposal
        # We have to do it explicitly (without, for example,
        # np.multivariate_normal) to make it work
        # with numba. Worth it!
        eps0 = np.random.normal()
        eps1 = np.random.normal()
        new_theta = np.array([
            thetas[i-1, 0] + proposal_sd * eps0,
            thetas[i-1, 1] + proposal_sd * eps1
        ])
        
        # Run particle filter using this new parameter value
        new_xss, new_aass, new_log_lik = particle_filter(
                                    temp=temp,
                                    n_particles=n_particles,
                                    ys=ys,
                                    us=us,
                                    theta=new_theta,
                                    alternative_tempering=alternative_tempering)
        
        # Sample value uniform on [0,1]
        d = np.random.uniform(0,1)
        
        # Compute log of the acceptance probability
        log_alpha = new_log_lik + log_prior(new_theta) - \
                    log_lik - log_prior(thetas[i-1])
        
        # If d < min(alpha,1), keep thetas[i], xss[:,:,i], aas[:,:,i] the same.
        # Otherwise, change them back to their previous values.
        if np.log(d) < min(log_alpha, 0):
            log_lik = new_log_lik
            xss[i,:,:] = new_xss
            aass[i,:,:] = new_aass
            thetas[i] = new_theta
            log_liks[i] = log_lik
            n_accepts += 1
        else:
            thetas[i] = thetas[i-1]
            log_liks[i] = log_lik
            xss[i,:,:] = xss[i-1,:,:]
            aass[i,:,:] = aass[i-1,:,:]
    
    accept_rate = n_accepts / n_iters
    return thetas[1:], xss[1:,:,:], aass[1:,:,:], log_liks, accept_rate


@njit
def adaptive_particle_metropolis_hastings(
    theta, 
    xs,
    aas,
    log_lik, 
    us,
    ys,
    temp,
    proposal_chol,
    n_iters=1, 
    verbose=False,
    alternative_tempering=False
    ):
    """Draw samples from the posterior ``p(theta|y_1:T,temp)`` 
    of the tempered non-linear state space model described above,
    using a random-walk particle Metropolis-Hastings algorithm with 
    bivariate normal proposal.
    This is an adaptive version of the PMMH algorithm, taking as random
    walk parameter the Cholesky decomposition of its desired covariance
    matrix, rather than a numerical standard deviation.
    
    Parameters
    -
    theta         : ndarray of shape (2,)
                    Initial parameter value
    xs            : ndarray of shape (n_particles,T)
                    Particles used for sampling the initial
                    parameter value
    aas           : ndarray of shape (n_particles,T-1)
                    Internal resampling state of the particle
                    filter used for sampling the initial parameter
                    value
    log_lik       : np.float64
                    Log-likelihood obtained from the particle filter
                    used when sampling the initial parameter value
    temp          : float
                    Tempering parameter of the distribution to sample
                    from.
    ys            : ndarray of shape (T,)
                    List of observations on which the distribution to
                    sample from is conditioned.
    n_iters       : int, default=1
                    Number of iterations to run the Metropolis-Hastings
                    algorithm for.
    proposal_chol : ndarray of shape (2,2)
                    Cholesky decomposition of the covariance matrix of the propoosal distribution
    verbose       : Boolean, default=False
                    Whether or not to print additional diagnostic information
                    while running the algorithm
                    
    Returns
    -
    thetas : ndarray of shape (n_iters,2)
             List of M-H parameter samples
    xss    : ndarray of shape (n_iters, n_particles,T)
             List of internal particles for estimation of M-H samples
    aass   : ndarray of shape (n_iters,n_particles,T-1)
             List of internal particle filter resampling states for
             estimation of M-H samples
    """
    T = len(ys) # Number of observations
    n_particles = xs.shape[0] # Number of particles
    n_accepts = 0 # Keep track of acceptance rate
    var = 0.01 + temp # Observation variance after tempering
    
    # Keep track of all samples, including the initial sample
    thetas = np.zeros(shape=(n_iters+1,2))
    thetas[0] = theta.flatten()

    log_liks = np.zeros(shape=(n_iters,)) # Keep track of sample log likelihoods
    
    # Keep track of all internal states, including the initial state
    xss = np.zeros(shape=(n_iters+1,n_particles,T))
    aass = np.zeros(shape=(n_iters+1,n_particles,T-1),dtype=np.int64)
    xss[0,:,:] = xs
    aass[0,:,:] = aas
     
    for i in range(1,n_iters+1):
        
        # Propose new parameter according to a
        # random walk proposal
        # We have to do it explicitly (without, for example,
        # np.multivariate_normal) to make it work
        # with numba. Worth it!
        eps0 = np.random.normal()
        eps1 = np.random.normal()
        delta_theta_0 = proposal_chol[0, 0] * eps0 + proposal_chol[0, 1] * eps1
        delta_theta_1 = proposal_chol[1, 0] * eps0 + proposal_chol[1, 1] * eps1
        
        new_theta = np.array([
            thetas[i-1, 0] + delta_theta_0,
            thetas[i-1, 1] + delta_theta_1
        ])
        
        # Run particle filter using this new parameter value
        new_xss, new_aass, new_log_lik = particle_filter(
                                    temp=temp,
                                    n_particles=n_particles,
                                    ys=ys,
                                    us=us,
                                    theta=new_theta,
                                    alternative_tempering=alternative_tempering)
        
        # Sample value uniform on [0,1]
        d = np.random.uniform(0,1)
        
        # Compute log of the acceptance probability
        log_alpha = new_log_lik + log_prior(new_theta) - \
                    log_lik - log_prior(thetas[i-1])
        
        # If d < min(alpha,1), keep thetas[i], xss[:,:,i], aas[:,:,i] the same.
        # Otherwise, change them back to their previous values.
        if np.log(d) < min(log_alpha, 0):
            log_lik = new_log_lik
            xss[i,:,:] = new_xss
            aass[i,:,:] = new_aass
            thetas[i] = new_theta
            log_liks[i] = log_lik
            n_accepts += 1
        else:
            thetas[i] = thetas[i-1]
            log_liks[i] = log_lik
            xss[i,:,:] = xss[i-1,:,:]
            aass[i,:,:] = aass[i-1,:,:]
    
    accept_rate = n_accepts / n_iters
    return thetas[1:], xss[1:,:,:], aass[1:,:,:], log_liks, accept_rate

# %%
""" Test whether the PMH sampling works by sampling
an intiial estimate from the posterior p(theta|y_1:T,temp)
"""

temp = 10 # Initial tempering
T = 100 # Number of observations
                              
# Exogenous input variables
rng = np.random.default_rng(seed=42) # Want to fix this while keeping the rest random
us = rng.normal(loc=0, scale=1, size=T)

# Sample observations from true state-space model
ys = sample_state_space_model(T=T,us=us,rng=rng)

# Sample theta from parameter prior
theta = sample_prior()

# Generate particle approximations for p(y_t|x_1:T,theta,temp)
# for the initial parameter sample
t0 = time.time()
xs, aas, log_lik = particle_filter(temp=temp,
                          n_particles=300,
                          ys=ys,
                          us=us,
                          theta=theta,
                          alternative_tempering=False
                          )
t1 = time.time()
print(f'Particle filter took {t1 - t0}s')

# Run PMH
t0 = time.time()

samples, xss, aass, log_liks, accept_rate = particle_metropolis_hastings(
    xs=xs,
    aas=aas,
    log_lik=log_lik,
    theta=theta,
    ys=ys,
    us=us,
    temp=temp,
    n_iters=300,
    proposal_sd=0.01,
    verbose=True,
    alternative_tempering=False
)
t1 = time.time()
print(f'PMH took {t1 - t0}s')
print(f'Acceptance rate of initial PMH sample: {accept_rate}')

# Plot result
plt.plot(samples[:,0],label=r'$\theta_1$')
plt.plot(samples[:,1],label=r'$\theta_2$')
plt.xlabel('PMH iteration')
plt.ylabel('Parameter value')
plt.legend()
# Out:
# Particle filter took 0.003632783889770508s
# PMH took 1.0181019306182861s
# Acceptance rate of initial PMH sample: 0.8766666666666667

# %%
""" Implementation of the complete algorithm described in
Svensson et al., applied to their example nonlinear state-space
model.
"""

@njit
def ess(cur_log_pos, nxt_log_pos):
    """Compute the effective sample size for the set
    of weights the log of which is given by nxt_log_pos - cur_log_pos.
    
    Parameters
    -
    cur_log_opos  : ndarray of size (N,)
                    List of logs of evaluations of the 'proposal distribution'
                    (up to proportionality) in a set of sample points.
    nxt_log_pos   : ndarray of size (N,)
                    List of logs of evaluations of the 'true distribution'
                    (up to proportionality) in a set of sample points.
    
    Comments
    -
    Works in log-scale to avoid numerical difficulties.
    """
    
    cur = np.asarray(cur_log_pos)
    nxt = np.asarray(nxt_log_pos)

    log_w = nxt - cur

    m = np.max(log_w)
    w = np.exp(log_w - m)
    w = w / np.sum(w)

    return 1.0 / np.sum(w**2)


@njit
def get_log_pos(temp, thetas, ys, xss, aass, alternative_tempering=False):
    """ Compute the log of the
    posterior p(theta,(xs,aas)|temp,ys)
    up to proportionality.
    
    Parameters
    -
    temp   : float
             tempering parameter
    thetas : ndarray of size (n_sample_particles,2)
             list of parameter samples
    ys     : ndarray of size (T,)
             list of observations from the
             true state-space model
    xss    : ndarray of size (n_filter_particles,T,n_sample_particles)
             list of particles obtained for estimation
             of likelihoods p(ys|theta,(xs,aas),temp)
    aass   : ndarray of size (n_filter_particles,T-1,n_sample_particles)
             list of resampling indices obtained for
             estimation of likelihoods
             p(ys|theta,(xs,aas),temp)
    
    Returns
    -
    log_pos : ndarray of size (n_sample_particles,)
            list of logs of posteriors p(theta,(xs,aas)|temp,ys) up to
            proportionality, for theta in thetas
    """
    # recall xss.shape = (n_sample_particles,n_filter_particles,T)
    n_sample_particles, n_filter_particles, T = xss.shape
    
    var = 0.01
    if alternative_tempering == False: # Only change variance when using standard tempering scheme
        var = 0.01 + temp 
    
    log_pos = np.zeros(n_sample_particles, dtype=np.float64)
    
    # Avoids unnecessary allocations
    inner = np.empty(n_filter_particles, dtype=np.float64)
    
    for m in range(n_sample_particles):
        theta_m = thetas[m]
        log_pos_m = 0.0
        
        for t in range(T):
            y_t = ys[t]
            
            # Calculate inner log-pdfs
            for n in range(n_filter_particles):
                if alternative_tempering == False:
                    inner[n] = normal_logpdf(y_t, loc=g(xss[m, n, t], theta_m), scale=var)
                else: # Because f(y_1|x_1,theta,temp) = f(y_1|x_1,theta)^(1/temp) under alternative tempering scheme
                    inner[n] = normal_logpdf(y_t, loc=g(xss[m, n, t], theta_m), scale=var) / temp
            
            lse = logsumexp(inner) 
            log_pos_m += lse

            # Second term for 0 to T-2
            if t < T - 1:
                for n in range(n_filter_particles):
                    idx = aass[m, n, t]
                    if alternative_tempering == False:
                        log_pos_m += normal_logpdf(y_t, loc=g(xss[m, idx, t], theta_m), scale=var) - lse
                    else:
                        log_pos_m += (normal_logpdf(y_t, loc=g(xss[m, idx, t], theta_m), scale=var) / temp) - lse
                    
        log_pos[m] = log_pos_m
        
    return log_pos


@njit
def bisect(prev_log_pos, 
           thetas, 
           ys, 
           xss, 
           aass, 
           c, 
           lo, 
           hi, 
           max_iter=50, 
           tol=1e-2, 
           verbose=False,
           alternative_tempering=False):
    """ Approximately compute the point of
    intersection between func_to_bisect 
    and the line y = c using the bisection method.
    
    Parameters
    -
    prev_log_pos : ndarray of shape (n_sample_particles,)
                 List of log of posteriors (up to proportionality)
                 for the previous tempering value
    thetas     : ndarray of shape (n_sample_particles,)
                 List of sample particles
    ys         : ndarray of shape (T,)
                 List of observations from the true
                 state-space model
    xss        : ndarray of shape (n_particles,T,n_sample_particles)
                 All particles used in likelihood approximation
                 corresponding to parameter values in thetas
    aass       : ndarray of shape (n_particles,T-1,n_sample_particles)
                 All resampling indices used in likelihood approxmimation
                 corresponding to parameter values in thetas
    c          : float
                 y-coordinate of the intersection line.
    lo         : float
                 x-coordinate of the lower extent of the 
                 initial bisection interval.
    hi         : float
                 x-coordinate of the upper extent of the
                 initial bisection interval.
    max_iter   : int
                 Number of iterations to try bisection for.
    tol        : float
                 How close to c a result can be to count
                 as an intersection. 
    verbose    : Boolean, default=False
                 Whether or not to display additional
                 diagnostic information.

    Returns
    -
    Tempering parameter for which the equation
    approximately holds.
    """
    
    # Evaluate lower bound
    nxt_log_pos_lo = get_log_pos(lo, thetas, ys, xss, aass, alternative_tempering)
    flo = ess(prev_log_pos, nxt_log_pos_lo) - c
    
    # Impossible in this case, return
    if flo > 0:
        return lo, nxt_log_pos_lo
        
    # Evaluate upper bound
    nxt_log_pos_hi = get_log_pos(hi, thetas, ys, xss, aass, alternative_tempering)
    fhi = ess(prev_log_pos, nxt_log_pos_hi) - c
    
    # Impossible in this case, return
    if flo * fhi > 0:
        return (lo + hi) / 2, nxt_log_pos_hi

    mid = (lo + hi) / 2
    nxt_log_pos_mid = get_log_pos(mid, thetas, ys, xss, aass, alternative_tempering)

    
    for i in range(max_iter):
        mid = (lo + hi) / 2
        nxt_log_pos_mid = get_log_pos(mid, thetas, ys, xss, aass, alternative_tempering)
        fmid = ess(prev_log_pos, nxt_log_pos_mid) - c
                
        # Found midpoint
        if np.abs(fmid) < tol:
            return mid, nxt_log_pos_mid
        
        # Sign check
        if flo * fmid < 0:
            hi = mid
            fhi = fmid
        else:
            lo = mid
            flo = fmid

    return (lo + hi) / 2, nxt_log_pos_mid


@njit(parallel=True)
def run_parallel_mutation(thetas, 
                          xss, 
                          aass, 
                          log_liks, 
                          temp, 
                          ys, 
                          us, 
                          mh_iters, 
                          mh_sd,
                          alternative_tempering=False,
                          adaptive_pmh=False):
    """ Mutate particles using PMMH in parallel
    """
    n_samples = thetas.shape[0]
    accept_rates = np.empty(n_samples, dtype=np.float64)

    if adaptive_pmh and temp < 1: # Only start adapting later on. The threshold is arbitrary
        # Do the adaptive Cholesky decomposition thing
        cov = np.cov(thetas, rowvar=False)
        scaled_cov = (2.38**2 / 2.0) * cov + np.eye(2) * 1e-6
        proposal_chol = np.linalg.cholesky(scaled_cov)
        
        for m in prange(n_samples):
            # We pass slices. Note: slicing the last dimension [:,:,m] is 
            # slow in NumPy but Numba handles it reasonably well.
            # Ensure particle_metropolis_hastings is @njit
            theta_chain, xss_chain, aass_chain, log_lik_chain, acc = adaptive_particle_metropolis_hastings(
                theta=thetas[m],
                xs=xss[m,:,:],
                aas=aass[m,:,:],
                temp=temp,
                log_lik=log_liks[m],
                ys=ys,
                us=us,
                n_iters=mh_iters,
                proposal_chol=proposal_chol,
                verbose=False,
                alternative_tempering=alternative_tempering,
            )
            
            # Update the main arrays with the last link in the MH chain
            thetas[m] = theta_chain[-1]
            log_liks[m] = log_lik_chain[-1]
            xss[m,:,:] = xss_chain[-1,:,:]
            aass[m,:,:] = aass_chain[-1,:,:]
            accept_rates[m] = acc
            
    else: # PMMH without adaptation
    
        # Numba will distribute these iterations across all CPU cores
        for m in prange(n_samples):
            # We pass slices. Note: slicing the last dimension [:,:,m] is 
            # slow in NumPy but Numba handles it reasonably well.
            # Ensure particle_metropolis_hastings is @njit
            theta_chain, xss_chain, aass_chain, log_lik_chain, acc = particle_metropolis_hastings(
                theta=thetas[m],
                xs=xss[m,:,:],
                aas=aass[m,:,:],
                temp=temp,
                log_lik=log_liks[m],
                ys=ys,
                us=us,
                n_iters=mh_iters,
                proposal_sd=mh_sd,
                verbose=False,
                alternative_tempering=alternative_tempering,
            )

            # Update the main arrays with the last link in the MH chain
            thetas[m] = theta_chain[-1]
            log_liks[m] = log_lik_chain[-1]
            xss[m,:,:] = xss_chain[-1,:,:]
            aass[m,:,:] = aass_chain[-1,:,:]
            accept_rates[m] = acc

    return accept_rates.mean()


def smc_sampler(ys, 
                us, 
                initial_mh_iters, 
                initial_mh_sd, 
                mh_iters, 
                mh_sd, 
                n_sample_particles,
                n_filter_particles, 
                temp, 
                min_temp, 
                alpha,
                max_smc_iters=30, 
                verbose=False,
                alternative_tempering=False,
                adaptive_pmh=False
                ):
    """Tempered SMC sampler for approximate sampling from the
    parameter posterior of the linear-Gaussian state space model
    described in Svensson et al. (2017).
    
    Parameters
    -
    ys                    : ndarray of size (T,)
                            List of observations to condition on in the posterior.
    us                    : ndarray of size (T,)
                            List of exogenous input variables in the state-space model.
    initial_mh_iters      : int
                            Number of iterations to run the Metropolis-Hastings
                            kernel for the initial sample.
    initial_mh_sd         : float
                            Standard deviation of the proposal distribution in the
                            Metropolis-Hastings kernel for the initial sample.
    mh_iters              : int
                            Number of iterations to run the mutation Metropolis-Hastings
                            kernel for.
    mh_sd                 : float
                            Standard deviation of the proposal distribution in the mutation
                            Metropolis-Hastings kernel.
    n_sample_particles    : int
                            Number of particles to simulate / number of samples to draw.
    n_filter_particles    : int
                            Number of particles to use for particle filtering
    temp: float
                            Initial tempering parameter.
    min_temp              : float
                            Minimum tempering parameter; when reaching at most this temperature,
                            terminate.
    alpha                 : float
                            Adaptive tempering such that ESS remains approximately alpha * n_sample_particles
    max_smc_iters         : int
                            How many tempering iterations of the SMC sampler are allowed before
                            we forcibly terminate.
    verbose               : Boolean, default=False
                            Whether or not to display additional diagnostic information
    alternative_tempering : Boolean, default=False
                            Whether to apply tempering in another way (see report)
    adaptive_pmh          : Boolean, default=False
                            Whether to keep mutation PMMH sd fixed, or to adapt it
                            to the the covariance of the particles                       
                            
    Returns
    -
    samples : ndarray of size (n_particles,2)
              Approximate samples from the posterior p(theta|y_1:T,temp)
    iteration_records : dictionary containing some diagnostic data
    """
    
    T = len(ys) # Number of observations
    p = 0 # Iteration counter
    iteration_records = {} # Keep diagnostic information
    ess_target = alpha * n_sample_particles # Aim to keep this ESS

    ######## Initial sample ########
    
    theta = sample_prior() # Starting parameter from prior
    
    # Particle filter, because particle approximations of
    # p(y_t|x_1:T,theta,temp) are needed for PMH
    xs, aas, log_lik = particle_filter(
                            n_particles=n_filter_particles,
                            temp=temp,
                            ys=ys,
                            us=us,
                            theta=theta,
                            alternative_tempering=alternative_tempering)
    
    # Draw the initial sample using PMH,
    # using a burn-in period of size initial_mh_iters - n_particles
    thetas, xss, aass, log_liks, mean_accept_rate = particle_metropolis_hastings(
                                        theta=theta,
                                        xs=xs,
                                        aas=aas,
                                        temp=temp,
                                        log_lik=log_lik,
                                        us=us,
                                        ys=ys,
                                        n_iters=initial_mh_iters,
                                        proposal_sd=initial_mh_sd,
                                        verbose=False,
                                        alternative_tempering=alternative_tempering)
    thetas = thetas[-n_sample_particles:]
    log_liks = log_liks[-n_sample_particles:]
    xss = xss[-n_sample_particles:,:,:]
    aass = aass[-n_sample_particles:,:,:]
        
    ######## While tempering not sufficiently small... ########
    
    while temp > min_temp:
        
        # Update diagnostics
        iteration_records[p] = {'temp': temp, 
                                'particles': thetas,
                                'log_likelihoods': log_liks,
                                'accept_rate': mean_accept_rate}
        
        p = p + 1 # Counter update

        if verbose:
            print(f'New iteration: p = {p}')
        
        ######## Adaptive tempering ########

        # Compute proportional log posterior for all samples
        # under the current tempering
        log_pos = get_log_pos(temp=temp,
                        thetas=thetas,
                        ys=ys,
                        xss=xss,
                        aass=aass)

        if verbose:
            print(f'Starting bisection...')
            t0 = time.time()

        # Intersect with ess_target to
        # find next tempering parameter
        temp, nxt_log_pos = bisect(prev_log_pos=log_pos,
                          thetas=thetas,
                          ys=ys,
                          xss=xss,
                          aass=aass,
                          c=ess_target,
                          lo=min_temp,
                          hi=temp,
                          verbose=False,
                          alternative_tempering=alternative_tempering)

        if verbose:
            t1 = time.time()
            print(f'Updated temperature, new temperature is: {temp}')
            print(f'Bisection took {t1-t0}s')

        ######## Normalize weights and resample ########

        log_w = nxt_log_pos - log_pos # weights propto next posterior / prev posterior
        w_norm = np.exp(log_w - logsumexp(log_w)) # Normalize

        idxs = multinomial_resample(w_norm) # Resampling indices

        # Resample
        thetas = thetas[idxs]
        log_liks = log_liks[idxs]
        xss = xss[idxs,:,:]
        aass = aass[idxs,:,:]
        
        ######## Mutate using PMH ########

        if verbose:
            print(f'Starting mutation...')
            t0 = time.time()

        # This one line replaces the entire mutation loop/pool logic
        mean_accept_rate = run_parallel_mutation(
                                            thetas=thetas, 
                                            xss=xss, 
                                            aass=aass, 
                                            log_liks=log_liks, 
                                            temp=temp, 
                                            ys=ys, 
                                            us=us, 
                                            mh_iters=mh_iters, 
                                            mh_sd=mh_sd,
                                            alternative_tempering=alternative_tempering,
                                            adaptive_pmh=adaptive_pmh
                                            )

        if verbose:
            t1 = time.time()
            print(f'Finished mutation. Mutation took {t1-t0}s')
            print(f'Mean accept rate: {mean_accept_rate}')

        # If accept rates of mutation steps are too bad,
        # terminate (heuristic from paper).
        if mean_accept_rate < 0.05:
            break 


    # Final diagnostic update
    iteration_records[p] = {'temp': temp, 
                            'particles': thetas,
                            'log_likelihoods': log_liks,
                            'accept_rate': mean_accept_rate}
    return thetas, iteration_records

# %%
temp = 10.0 # Initial tempering
T = 200 # Number of observations
                              
# Exogenous input variables
rng = np.random.default_rng(seed=42) # Want to fix this while keeping the rest random
us = rng.normal(loc=0, scale=1, size=T)

# Sample observations from true state-space model
ys = sample_state_space_model(T=T,us=us,rng=rng)

samples, records = smc_sampler(
    ys=ys,
    us=us,
    initial_mh_iters=300,
    initial_mh_sd=0.5,
    mh_iters=10,
    mh_sd=0.1,
    n_sample_particles=100,
    n_filter_particles=300,
    temp=temp,
    min_temp=0.01,
    alpha=0.4,
    verbose=True,
    alternative_tempering=False,
    adaptive_pmh=True
)
# Out:
# New iteration: p = 1
# Starting bisection...
# Updated temperature, new temperature is: 9.55199264526367
# Bisection took 1.9545612335205078s
# Starting mutation...
# Finished mutation. Mutation took 11.892420053482056s
# Mean accept rate: 0.747
# New iteration: p = 2
# Starting bisection...
# Updated temperature, new temperature is: 9.149046712558484
# Bisection took 1.1496787071228027s
# Starting mutation...
# Finished mutation. Mutation took 0.7599201202392578s
# Mean accept rate: 0.737
# New iteration: p = 3
# Starting bisection...
# Updated temperature, new temperature is: 8.71786488218692
# Bisection took 1.0686461925506592s
# Starting mutation...
# Finished mutation. Mutation took 0.7596406936645508s
# Mean accept rate: 0.7580000000000001
# New iteration: p = 4
# Starting bisection...
# Updated temperature, new temperature is: 8.351671101435773
# Bisection took 1.0302278995513916s
# Starting mutation...
# Finished mutation. Mutation took 0.7670392990112305s
# Mean accept rate: 0.7439999999999999
# New iteration: p = 5
# Starting bisection...
# Updated temperature, new temperature is: 8.045489921099717
# Bisection took 1.2115504741668701s
# Starting mutation...
# Finished mutation. Mutation took 0.7985305786132812s
# Mean accept rate: 0.7310000000000002
# New iteration: p = 6
# Starting bisection...
# Updated temperature, new temperature is: 7.734546280354037
# Bisection took 0.9624378681182861s
# Starting mutation...
# Finished mutation. Mutation took 0.8412790298461914s
# Mean accept rate: 0.7219999999999999
# New iteration: p = 7
# Starting bisection...
# Updated temperature, new temperature is: 7.398624696812028
# Bisection took 1.1883447170257568s
# Starting mutation...
# Finished mutation. Mutation took 0.8323464393615723s
# Mean accept rate: 0.721
# New iteration: p = 8
# Starting bisection...
# Updated temperature, new temperature is: 7.214066917443723
# Bisection took 1.143904209136963s
# Starting mutation...
# Finished mutation. Mutation took 0.8266005516052246s
# Mean accept rate: 0.7359999999999998
# New iteration: p = 9
# Starting bisection...
# Updated temperature, new temperature is: 6.92133574372008
# Bisection took 1.1678268909454346s
# Starting mutation...
# Finished mutation. Mutation took 0.8351364135742188s
# Mean accept rate: 0.7160000000000001
# New iteration: p = 10
# Starting bisection...
# Updated temperature, new temperature is: 6.702087284686968
# Bisection took 1.1249871253967285s
# Starting mutation...
# Finished mutation. Mutation took 0.905463457107544s
# Mean accept rate: 0.7130000000000001
# New iteration: p = 11
# Starting bisection...
# Updated temperature, new temperature is: 6.4421072092045915
# Bisection took 1.096921443939209s
# Starting mutation...
# Finished mutation. Mutation took 0.8365771770477295s
# Mean accept rate: 0.716
# New iteration: p = 12
# Starting bisection...
# Updated temperature, new temperature is: 6.225007887507195
# Bisection took 1.0318124294281006s
# Starting mutation...
# Finished mutation. Mutation took 0.845372200012207s
# Mean accept rate: 0.722
# New iteration: p = 13
# Starting bisection...
# Updated temperature, new temperature is: 6.016658700360385
# Bisection took 1.1524624824523926s
# Starting mutation...
# Finished mutation. Mutation took 0.7242634296417236s
# Mean accept rate: 0.705
# New iteration: p = 14
# Starting bisection...
# Updated temperature, new temperature is: 5.784773225019936
# Bisection took 1.0474803447723389s
# Starting mutation...
# Finished mutation. Mutation took 0.732581377029419s
# Mean accept rate: 0.7160000000000001
# New iteration: p = 15
# Starting bisection...
# Updated temperature, new temperature is: 5.584132987083987
# Bisection took 1.130924940109253s
# Starting mutation...
# Finished mutation. Mutation took 0.7314252853393555s
# Mean accept rate: 0.693
# New iteration: p = 16
# Starting bisection...
# Updated temperature, new temperature is: 5.443750502721468
# Bisection took 1.157956600189209s
# Starting mutation...
# Finished mutation. Mutation took 0.8413963317871094s
# Mean accept rate: 0.6960000000000001
# New iteration: p = 17
# Starting bisection...
# Updated temperature, new temperature is: 5.281615201389805
# Bisection took 1.2211740016937256s
# Starting mutation...
# Finished mutation. Mutation took 0.8258512020111084s
# Mean accept rate: 0.7020000000000001
# New iteration: p = 18
# Starting bisection...
# Updated temperature, new temperature is: 5.124036249675898
# Bisection took 1.1255521774291992s
# Starting mutation...
# Finished mutation. Mutation took 0.9048917293548584s
# Mean accept rate: 0.6689999999999999
# New iteration: p = 19
# Starting bisection...
# Updated temperature, new temperature is: 4.948381714793994
# Bisection took 1.1421480178833008s
# Starting mutation...
# Finished mutation. Mutation took 0.7721748352050781s
# Mean accept rate: 0.6639999999999999
# New iteration: p = 20
# Starting bisection...
# Updated temperature, new temperature is: 4.8101829833344585
# Bisection took 1.0707881450653076s
# Starting mutation...
# Finished mutation. Mutation took 0.7069706916809082s
# Mean accept rate: 0.665
# New iteration: p = 21
# Starting bisection...
# Updated temperature, new temperature is: 4.654976871553365
# Bisection took 1.099928617477417s
# Starting mutation...
# Finished mutation. Mutation took 0.6974484920501709s
# Mean accept rate: 0.66
# New iteration: p = 22
# Starting bisection...
# Updated temperature, new temperature is: 4.517759537213044
# Bisection took 0.8394560813903809s
# Starting mutation...
# Finished mutation. Mutation took 0.6774053573608398s
# Mean accept rate: 0.6579999999999999
# New iteration: p = 23
# Starting bisection...
# Updated temperature, new temperature is: 4.3758603073962945
# Bisection took 1.0955498218536377s
# Starting mutation...
# Finished mutation. Mutation took 0.6927127838134766s
# Mean accept rate: 0.6509999999999999
# New iteration: p = 24
# Starting bisection...
# Updated temperature, new temperature is: 4.28382789750451
# Bisection took 1.1506850719451904s
# Starting mutation...
# Finished mutation. Mutation took 0.7218327522277832s
# Mean accept rate: 0.657
# New iteration: p = 25
# Starting bisection...
# Updated temperature, new temperature is: 4.177823453421966
# Bisection took 1.1912002563476562s
# Starting mutation...
# Finished mutation. Mutation took 0.7766604423522949s
# Mean accept rate: 0.638
# New iteration: p = 26
# Starting bisection...
# Updated temperature, new temperature is: 4.06328716741713
# Bisection took 1.0909619331359863s
# Starting mutation...
# Finished mutation. Mutation took 0.7702343463897705s
# Mean accept rate: 0.635
# New iteration: p = 27
# Starting bisection...
# Updated temperature, new temperature is: 3.9918524341656836
# Bisection took 1.1499981880187988s
# Starting mutation...
# Finished mutation. Mutation took 0.8493227958679199s
# Mean accept rate: 0.62
# New iteration: p = 28
# Starting bisection...
# Updated temperature, new temperature is: 3.900350515131054
# Bisection took 1.0497372150421143s
# Starting mutation...
# Finished mutation. Mutation took 0.8152439594268799s
# Mean accept rate: 0.6459999999999999
# New iteration: p = 29
# Starting bisection...
# Updated temperature, new temperature is: 3.8215770908515907
# Bisection took 1.1383559703826904s
# Starting mutation...
# Finished mutation. Mutation took 0.8001687526702881s
# Mean accept rate: 0.645
# New iteration: p = 30
# Starting bisection...
# Updated temperature, new temperature is: 3.7278521689474875
# Bisection took 1.1644740104675293s
# Starting mutation...
# Finished mutation. Mutation took 0.7535393238067627s
# Mean accept rate: 0.643
# New iteration: p = 31
# Starting bisection...
# Updated temperature, new temperature is: 3.6422467166320915
# Bisection took 1.101062536239624s
# Starting mutation...
# Finished mutation. Mutation took 0.7557532787322998s
# Mean accept rate: 0.6439999999999999
# New iteration: p = 32
# Starting bisection...
# Updated temperature, new temperature is: 3.5761539705141745
# Bisection took 1.1913301944732666s
# Starting mutation...
# Finished mutation. Mutation took 0.7675530910491943s
# Mean accept rate: 0.6329999999999999
# New iteration: p = 33
# Starting bisection...
# Updated temperature, new temperature is: 3.505822335887564
# Bisection took 1.1744914054870605s
# Starting mutation...
# Finished mutation. Mutation took 0.6845760345458984s
# Mean accept rate: 0.6
# New iteration: p = 34
# Starting bisection...
# Updated temperature, new temperature is: 3.4400783016318663
# Bisection took 1.1686127185821533s
# Starting mutation...
# Finished mutation. Mutation took 0.7495417594909668s
# Mean accept rate: 0.622
# New iteration: p = 35
# Starting bisection...
# Updated temperature, new temperature is: 3.368740460977505
# Bisection took 1.122502326965332s
# Starting mutation...
# Finished mutation. Mutation took 0.7958827018737793s
# Mean accept rate: 0.617
# New iteration: p = 36
# Starting bisection...
# Updated temperature, new temperature is: 3.297374401225442
# Bisection took 1.152817964553833s
# Starting mutation...
# Finished mutation. Mutation took 0.7538981437683105s
# Mean accept rate: 0.633
# New iteration: p = 37
# Starting bisection...
# Updated temperature, new temperature is: 3.226245603298536
# Bisection took 1.0857298374176025s
# Starting mutation...
# Finished mutation. Mutation took 0.7457635402679443s
# Mean accept rate: 0.618
# New iteration: p = 38
# Starting bisection...
# Updated temperature, new temperature is: 3.1708019773475096
# Bisection took 1.210747241973877s
# Starting mutation...
# Finished mutation. Mutation took 0.7059609889984131s
# Mean accept rate: 0.629
# New iteration: p = 39
# Starting bisection...
# Updated temperature, new temperature is: 3.123681256951566
# Bisection took 1.1133997440338135s
# Starting mutation...
# Finished mutation. Mutation took 0.8141603469848633s
# Mean accept rate: 0.6239999999999999
# New iteration: p = 40
# Starting bisection...
# Updated temperature, new temperature is: 3.071609194915145
# Bisection took 0.9123435020446777s
# Starting mutation...
# Finished mutation. Mutation took 0.7495524883270264s
# Mean accept rate: 0.6200000000000001
# New iteration: p = 41
# Starting bisection...
# Updated temperature, new temperature is: 3.005633889960327
# Bisection took 1.2282309532165527s
# Starting mutation...
# Finished mutation. Mutation took 0.8101418018341064s
# Mean accept rate: 0.637
# New iteration: p = 42
# Starting bisection...
# Updated temperature, new temperature is: 2.9464397693625086
# Bisection took 1.101538896560669s
# Starting mutation...
# Finished mutation. Mutation took 0.753225564956665s
# Mean accept rate: 0.591
# New iteration: p = 43
# Starting bisection...
# Updated temperature, new temperature is: 2.8964356985829594
# Bisection took 0.9902091026306152s
# Starting mutation...
# Finished mutation. Mutation took 0.7626497745513916s
# Mean accept rate: 0.6260000000000001
# New iteration: p = 44
# Starting bisection...
# Updated temperature, new temperature is: 2.8511809884954653
# Bisection took 1.1530964374542236s
# Starting mutation...
# Finished mutation. Mutation took 0.8490877151489258s
# Mean accept rate: 0.6129999999999999
# New iteration: p = 45
# Starting bisection...
# Updated temperature, new temperature is: 2.79820364523464
# Bisection took 1.1154212951660156s
# Starting mutation...
# Finished mutation. Mutation took 0.7441153526306152s
# Mean accept rate: 0.601
# New iteration: p = 46
# Starting bisection...
# Updated temperature, new temperature is: 2.7472990178310264
# Bisection took 1.1352269649505615s
# Starting mutation...
# Finished mutation. Mutation took 0.6995251178741455s
# Mean accept rate: 0.616
# New iteration: p = 47
# Starting bisection...
# Updated temperature, new temperature is: 2.7006443089242076
# Bisection took 1.1139628887176514s
# Starting mutation...
# Finished mutation. Mutation took 0.840735912322998s
# Mean accept rate: 0.614
# New iteration: p = 48
# Starting bisection...
# Updated temperature, new temperature is: 2.6484826940180763
# Bisection took 1.1454269886016846s
# Starting mutation...
# Finished mutation. Mutation took 0.7594029903411865s
# Mean accept rate: 0.6040000000000001
# New iteration: p = 49
# Starting bisection...
# Updated temperature, new temperature is: 2.601770969992587
# Bisection took 1.2490575313568115s
# Starting mutation...
# Finished mutation. Mutation took 0.8135347366333008s
# Mean accept rate: 0.61
# New iteration: p = 50
# Starting bisection...
# Updated temperature, new temperature is: 2.5579426896963486
# Bisection took 1.2157995700836182s
# Starting mutation...
# Finished mutation. Mutation took 0.7311570644378662s
# Mean accept rate: 0.613
# New iteration: p = 51
# Starting bisection...
# Updated temperature, new temperature is: 2.5232824890758607
# Bisection took 1.1617822647094727s
# Starting mutation...
# Finished mutation. Mutation took 0.747248649597168s
# Mean accept rate: 0.5800000000000001
# New iteration: p = 52
# Starting bisection...
# Updated temperature, new temperature is: 2.4820374433452534
# Bisection took 1.1182940006256104s
# Starting mutation...
# Finished mutation. Mutation took 0.7156879901885986s
# Mean accept rate: 0.587
# New iteration: p = 53
# Starting bisection...
# Updated temperature, new temperature is: 2.4333216786040364
# Bisection took 1.143007516860962s
# Starting mutation...
# Finished mutation. Mutation took 0.716663122177124s
# Mean accept rate: 0.5870000000000001
# New iteration: p = 54
# Starting bisection...
# Updated temperature, new temperature is: 2.3980826411328806
# Bisection took 1.0736911296844482s
# Starting mutation...
# Finished mutation. Mutation took 0.8013434410095215s
# Mean accept rate: 0.5600000000000002
# New iteration: p = 55
# Starting bisection...
# Updated temperature, new temperature is: 2.350802715185769
# Bisection took 1.1756823062896729s
# Starting mutation...
# Finished mutation. Mutation took 0.7474017143249512s
# Mean accept rate: 0.5459999999999999
# New iteration: p = 56
# Starting bisection...
# Updated temperature, new temperature is: 2.309512921198422
# Bisection took 0.9799401760101318s
# Starting mutation...
# Finished mutation. Mutation took 0.8282637596130371s
# Mean accept rate: 0.5870000000000001
# New iteration: p = 57
# Starting bisection...
# Updated temperature, new temperature is: 2.27781110960933
# Bisection took 1.2504773139953613s
# Starting mutation...
# Finished mutation. Mutation took 0.7171897888183594s
# Mean accept rate: 0.619
# New iteration: p = 58
# Starting bisection...
# Updated temperature, new temperature is: 2.2427658565994295
# Bisection took 1.205867052078247s
# Starting mutation...
# Finished mutation. Mutation took 0.8777623176574707s
# Mean accept rate: 0.5419999999999999
# New iteration: p = 59
# Starting bisection...
# Updated temperature, new temperature is: 2.202070073889041
# Bisection took 1.143193006515503s
# Starting mutation...
# Finished mutation. Mutation took 0.8719522953033447s
# Mean accept rate: 0.574
# New iteration: p = 60
# Starting bisection...
# Updated temperature, new temperature is: 2.170411224936771
# Bisection took 1.147653341293335s
# Starting mutation...
# Finished mutation. Mutation took 0.7645955085754395s
# Mean accept rate: 0.5760000000000001
# New iteration: p = 61
# Starting bisection...
# Updated temperature, new temperature is: 2.1455554195229176
# Bisection took 1.0190222263336182s
# Starting mutation...
# Finished mutation. Mutation took 0.7195734977722168s
# Mean accept rate: 0.5760000000000001
# New iteration: p = 62
# Starting bisection...
# Updated temperature, new temperature is: 2.118806395246171
# Bisection took 1.2769734859466553s
# Starting mutation...
# Finished mutation. Mutation took 0.8017363548278809s
# Mean accept rate: 0.5459999999999999
# New iteration: p = 63
# Starting bisection...
# Updated temperature, new temperature is: 2.0900555023910616
# Bisection took 1.1973512172698975s
# Starting mutation...
# Finished mutation. Mutation took 0.8514776229858398s
# Mean accept rate: 0.5509999999999999
# New iteration: p = 64
# Starting bisection...
# Updated temperature, new temperature is: 2.0533650702504964
# Bisection took 0.9620304107666016s
# Starting mutation...
# Finished mutation. Mutation took 0.8891780376434326s
# Mean accept rate: 0.5710000000000001
# New iteration: p = 65
# Starting bisection...
# Updated temperature, new temperature is: 2.02586494830285
# Bisection took 1.1025307178497314s
# Starting mutation...
# Finished mutation. Mutation took 0.804832935333252s
# Mean accept rate: 0.552
# New iteration: p = 66
# Starting bisection...
# Updated temperature, new temperature is: 2.001687857095482
# Bisection took 1.0310020446777344s
# Starting mutation...
# Finished mutation. Mutation took 0.7885222434997559s
# Mean accept rate: 0.5499999999999999
# New iteration: p = 67
# Starting bisection...
# Updated temperature, new temperature is: 1.9805055079073177
# Bisection took 1.0808792114257812s
# Starting mutation...
# Finished mutation. Mutation took 0.8352177143096924s
# Mean accept rate: 0.545
# New iteration: p = 68
# Starting bisection...
# Updated temperature, new temperature is: 1.955572010403165
# Bisection took 1.2050964832305908s
# Starting mutation...
# Finished mutation. Mutation took 0.8366405963897705s
# Mean accept rate: 0.5829999999999999
# New iteration: p = 69
# Starting bisection...
# Updated temperature, new temperature is: 1.9204373596110487
# Bisection took 1.1369073390960693s
# Starting mutation...
# Finished mutation. Mutation took 0.7550392150878906s
# Mean accept rate: 0.568
# New iteration: p = 70
# Starting bisection...
# Updated temperature, new temperature is: 1.894638759402678
# Bisection took 1.0860707759857178s
# Starting mutation...
# Finished mutation. Mutation took 0.9211874008178711s
# Mean accept rate: 0.545
# New iteration: p = 71
# Starting bisection...
# Updated temperature, new temperature is: 1.865579502408409
# Bisection took 1.1524176597595215s
# Starting mutation...
# Finished mutation. Mutation took 0.7098865509033203s
# Mean accept rate: 0.539
# New iteration: p = 72
# Starting bisection...
# Updated temperature, new temperature is: 1.834094449816274
# Bisection took 0.9170832633972168s
# Starting mutation...
# Finished mutation. Mutation took 0.7303051948547363s
# Mean accept rate: 0.542
# New iteration: p = 73
# Starting bisection...
# Updated temperature, new temperature is: 1.8107073745987121
# Bisection took 1.1873645782470703s
# Starting mutation...
# Finished mutation. Mutation took 0.7589759826660156s
# Mean accept rate: 0.517
# New iteration: p = 74
# Starting bisection...
# Updated temperature, new temperature is: 1.7847557126829945
# Bisection took 1.1464242935180664s
# Starting mutation...
# Finished mutation. Mutation took 0.7845079898834229s
# Mean accept rate: 0.5269999999999999
# New iteration: p = 75
# Starting bisection...
# Updated temperature, new temperature is: 1.7515684091262773
# Bisection took 1.1333129405975342s
# Starting mutation...
# Finished mutation. Mutation took 0.8163397312164307s
# Mean accept rate: 0.556
# New iteration: p = 76
# Starting bisection...
# Updated temperature, new temperature is: 1.7267480829830286
# Bisection took 1.0303843021392822s
# Starting mutation...
# Finished mutation. Mutation took 0.8939559459686279s
# Mean accept rate: 0.563
# New iteration: p = 77
# Starting bisection...
# Updated temperature, new temperature is: 1.7027399101001255
# Bisection took 1.2133629322052002s
# Starting mutation...
# Finished mutation. Mutation took 0.8123581409454346s
# Mean accept rate: 0.5050000000000001
# New iteration: p = 78
# Starting bisection...
# Updated temperature, new temperature is: 1.6807205501550513
# Bisection took 1.1435935497283936s
# Starting mutation...
# Finished mutation. Mutation took 0.8489861488342285s
# Mean accept rate: 0.5359999999999999
# New iteration: p = 79
# Starting bisection...
# Updated temperature, new temperature is: 1.652308409451502
# Bisection took 1.1378543376922607s
# Starting mutation...
# Finished mutation. Mutation took 0.7467894554138184s
# Mean accept rate: 0.538
# New iteration: p = 80
# Starting bisection...
# Updated temperature, new temperature is: 1.6371160041592963
# Bisection took 1.1997747421264648s
# Starting mutation...
# Finished mutation. Mutation took 0.6868832111358643s
# Mean accept rate: 0.5299999999999998
# New iteration: p = 81
# Starting bisection...
# Updated temperature, new temperature is: 1.6183027236394034
# Bisection took 1.1998345851898193s
# Starting mutation...
# Finished mutation. Mutation took 0.7993040084838867s
# Mean accept rate: 0.5379999999999999
# New iteration: p = 82
# Starting bisection...
# Updated temperature, new temperature is: 1.5971915417239555
# Bisection took 1.19429349899292s
# Starting mutation...
# Finished mutation. Mutation took 0.7359297275543213s
# Mean accept rate: 0.5209999999999999
# New iteration: p = 83
# Starting bisection...
# Updated temperature, new temperature is: 1.5726459694043569
# Bisection took 1.1557040214538574s
# Starting mutation...
# Finished mutation. Mutation took 0.8921043872833252s
# Mean accept rate: 0.5120000000000001
# New iteration: p = 84
# Starting bisection...
# Updated temperature, new temperature is: 1.5584468166519718
# Bisection took 1.1338977813720703s
# Starting mutation...
# Finished mutation. Mutation took 0.8610415458679199s
# Mean accept rate: 0.4830000000000001
# New iteration: p = 85
# Starting bisection...
# Updated temperature, new temperature is: 1.5413523758583971
# Bisection took 1.148780345916748s
# Starting mutation...
# Finished mutation. Mutation took 0.7817878723144531s
# Mean accept rate: 0.518
# New iteration: p = 86
# Starting bisection...
# Updated temperature, new temperature is: 1.5243707117477543
# Bisection took 1.1861872673034668s
# Starting mutation...
# Finished mutation. Mutation took 0.7916586399078369s
# Mean accept rate: 0.5209999999999998
# New iteration: p = 87
# Starting bisection...
# Updated temperature, new temperature is: 1.5069650150524416
# Bisection took 1.1951305866241455s
# Starting mutation...
# Finished mutation. Mutation took 0.721233606338501s
# Mean accept rate: 0.5269999999999999
# New iteration: p = 88
# Starting bisection...
# Updated temperature, new temperature is: 1.4867099838162088
# Bisection took 1.217996597290039s
# Starting mutation...
# Finished mutation. Mutation took 0.8255743980407715s
# Mean accept rate: 0.5240000000000001
# New iteration: p = 89
# Starting bisection...
# Updated temperature, new temperature is: 1.4635913247067815
# Bisection took 1.0334162712097168s
# Starting mutation...
# Finished mutation. Mutation took 0.7490966320037842s
# Mean accept rate: 0.515
# New iteration: p = 90
# Starting bisection...
# Updated temperature, new temperature is: 1.4414667314085177
# Bisection took 1.1368684768676758s
# Starting mutation...
# Finished mutation. Mutation took 0.8024554252624512s
# Mean accept rate: 0.513
# New iteration: p = 91
# Starting bisection...
# Updated temperature, new temperature is: 1.424369554528482
# Bisection took 1.193626880645752s
# Starting mutation...
# Finished mutation. Mutation took 0.8050394058227539s
# Mean accept rate: 0.5149999999999999
# New iteration: p = 92
# Starting bisection...
# Updated temperature, new temperature is: 1.4077139804362677
# Bisection took 1.2589683532714844s
# Starting mutation...
# Finished mutation. Mutation took 0.8257334232330322s
# Mean accept rate: 0.5169999999999999
# New iteration: p = 93
# Starting bisection...
# Updated temperature, new temperature is: 1.3901508477627862
# Bisection took 1.1604483127593994s
# Starting mutation...
# Finished mutation. Mutation took 0.8188149929046631s
# Mean accept rate: 0.45899999999999996
# New iteration: p = 94
# Starting bisection...
# Updated temperature, new temperature is: 1.374966998256607
# Bisection took 1.158430814743042s
# Starting mutation...
# Finished mutation. Mutation took 0.7333567142486572s
# Mean accept rate: 0.524
# New iteration: p = 95
# Starting bisection...
# Updated temperature, new temperature is: 1.3595700888715179
# Bisection took 1.310570240020752s
# Starting mutation...
# Finished mutation. Mutation took 0.7504198551177979s
# Mean accept rate: 0.4770000000000001
# New iteration: p = 96
# Starting bisection...
# Updated temperature, new temperature is: 1.3429156575761256
# Bisection took 1.4208323955535889s
# Starting mutation...
# Finished mutation. Mutation took 0.6960127353668213s
# Mean accept rate: 0.513
# New iteration: p = 97
# Starting bisection...
# Updated temperature, new temperature is: 1.3262125175647674
# Bisection took 1.2017982006072998s
# Starting mutation...
# Finished mutation. Mutation took 0.8135292530059814s
# Mean accept rate: 0.5099999999999999
# New iteration: p = 98
# Starting bisection...
# Updated temperature, new temperature is: 1.3128718473256256
# Bisection took 1.2076411247253418s
# Starting mutation...
# Finished mutation. Mutation took 0.7398102283477783s
# Mean accept rate: 0.47700000000000004
# New iteration: p = 99
# Starting bisection...
# Updated temperature, new temperature is: 1.3006107051772169
# Bisection took 1.208660364151001s
# Starting mutation...
# Finished mutation. Mutation took 0.7361574172973633s
# Mean accept rate: 0.46699999999999986
# New iteration: p = 100
# Starting bisection...
# Updated temperature, new temperature is: 1.284496779861188
# Bisection took 1.2009522914886475s
# Starting mutation...
# Finished mutation. Mutation took 0.7639646530151367s
# Mean accept rate: 0.473
# New iteration: p = 101
# Starting bisection...
# Updated temperature, new temperature is: 1.2692987324756058
# Bisection took 1.1677265167236328s
# Starting mutation...
# Finished mutation. Mutation took 0.7604107856750488s
# Mean accept rate: 0.4809999999999999
# New iteration: p = 102
# Starting bisection...
# Updated temperature, new temperature is: 1.2562995321502919
# Bisection took 1.1500554084777832s
# Starting mutation...
# Finished mutation. Mutation took 0.728339672088623s
# Mean accept rate: 0.4650000000000001
# New iteration: p = 103
# Starting bisection...
# Updated temperature, new temperature is: 1.2429353201718585
# Bisection took 1.189591884613037s
# Starting mutation...
# Finished mutation. Mutation took 0.6907169818878174s
# Mean accept rate: 0.46799999999999997
# New iteration: p = 104
# Starting bisection...
# Updated temperature, new temperature is: 1.2270382506902724
# Bisection took 1.0612843036651611s
# Starting mutation...
# Finished mutation. Mutation took 0.7019731998443604s
# Mean accept rate: 0.442
# New iteration: p = 105
# Starting bisection...
# Updated temperature, new temperature is: 1.2150741867710948
# Bisection took 1.2052831649780273s
# Starting mutation...
# Finished mutation. Mutation took 0.9357056617736816s
# Mean accept rate: 0.47
# New iteration: p = 106
# Starting bisection...
# Updated temperature, new temperature is: 1.1990858444035801
# Bisection took 1.1321187019348145s
# Starting mutation...
# Finished mutation. Mutation took 0.7630867958068848s
# Mean accept rate: 0.462
# New iteration: p = 107
# Starting bisection...
# Updated temperature, new temperature is: 1.186502973415209
# Bisection took 1.1652390956878662s
# Starting mutation...
# Finished mutation. Mutation took 0.7711193561553955s
# Mean accept rate: 0.486
# New iteration: p = 108
# Starting bisection...
# Updated temperature, new temperature is: 1.1705346598951158
# Bisection took 1.1560478210449219s
# Starting mutation...
# Finished mutation. Mutation took 0.8677639961242676s
# Mean accept rate: 0.48599999999999993
# New iteration: p = 109
# Starting bisection...
# Updated temperature, new temperature is: 1.1603877732966064
# Bisection took 1.0556411743164062s
# Starting mutation...
# Finished mutation. Mutation took 0.7233633995056152s
# Mean accept rate: 0.4629999999999999
# New iteration: p = 110
# Starting bisection...
# Updated temperature, new temperature is: 1.1452785771927085
# Bisection took 1.1836638450622559s
# Starting mutation...
# Finished mutation. Mutation took 0.8221688270568848s
# Mean accept rate: 0.48700000000000004
# New iteration: p = 111
# Starting bisection...
# Updated temperature, new temperature is: 1.1339883273653562
# Bisection took 1.1827759742736816s
# Starting mutation...
# Finished mutation. Mutation took 0.8627853393554688s
# Mean accept rate: 0.48200000000000004
# New iteration: p = 112
# Starting bisection...
# Updated temperature, new temperature is: 1.1226903032160043
# Bisection took 1.1912751197814941s
# Starting mutation...
# Finished mutation. Mutation took 0.777350664138794s
# Mean accept rate: 0.482
# New iteration: p = 113
# Starting bisection...
# Updated temperature, new temperature is: 1.1118241869736605
# Bisection took 0.6729540824890137s
# Starting mutation...
# Finished mutation. Mutation took 0.787003755569458s
# Mean accept rate: 0.472
# New iteration: p = 114
# Starting bisection...
# Updated temperature, new temperature is: 1.09972338804522
# Bisection took 1.178548812866211s
# Starting mutation...
# Finished mutation. Mutation took 0.8763833045959473s
# Mean accept rate: 0.46
# New iteration: p = 115
# Starting bisection...
# Updated temperature, new temperature is: 1.0893434468680465
# Bisection took 1.176964521408081s
# Starting mutation...
# Finished mutation. Mutation took 0.737396240234375s
# Mean accept rate: 0.47200000000000003
# New iteration: p = 116
# Starting bisection...
# Updated temperature, new temperature is: 1.0814504514622922
# Bisection took 1.1763033866882324s
# Starting mutation...
# Finished mutation. Mutation took 0.7255573272705078s
# Mean accept rate: 0.4280000000000001
# New iteration: p = 117
# Starting bisection...
# Updated temperature, new temperature is: 1.0691273652533428
# Bisection took 1.1962776184082031s
# Starting mutation...
# Finished mutation. Mutation took 0.7290380001068115s
# Mean accept rate: 0.4779999999999999
# New iteration: p = 118
# Starting bisection...
# Updated temperature, new temperature is: 1.0587560428251916
# Bisection took 1.1934752464294434s
# Starting mutation...
# Finished mutation. Mutation took 0.7006063461303711s
# Mean accept rate: 0.466
# New iteration: p = 119
# Starting bisection...
# Updated temperature, new temperature is: 1.0448856616588293
# Bisection took 1.2159254550933838s
# Starting mutation...
# Finished mutation. Mutation took 0.6864256858825684s
# Mean accept rate: 0.48699999999999993
# New iteration: p = 120
# Starting bisection...
# Updated temperature, new temperature is: 1.03582551687769
# Bisection took 1.1780669689178467s
# Starting mutation...
# Finished mutation. Mutation took 0.712554931640625s
# Mean accept rate: 0.44900000000000007
# New iteration: p = 121
# Starting bisection...
# Updated temperature, new temperature is: 1.026883823357848
# Bisection took 1.1787443161010742s
# Starting mutation...
# Finished mutation. Mutation took 0.6838219165802002s
# Mean accept rate: 0.455
# New iteration: p = 122
# Starting bisection...
# Updated temperature, new temperature is: 1.0172520082737813
# Bisection took 1.2250182628631592s
# Starting mutation...
# Finished mutation. Mutation took 0.8372831344604492s
# Mean accept rate: 0.451
# New iteration: p = 123
# Starting bisection...
# Updated temperature, new temperature is: 1.0053944807410782
# Bisection took 1.127953290939331s
# Starting mutation...
# Finished mutation. Mutation took 0.833723783493042s
# Mean accept rate: 0.474
# New iteration: p = 124
# Starting bisection...
# Updated temperature, new temperature is: 0.995635860229052
# Bisection took 1.136979579925537s
# Starting mutation...
# Finished mutation. Mutation took 0.7743315696716309s
# Mean accept rate: 0.38
# New iteration: p = 125
# Starting bisection...
# Updated temperature, new temperature is: 0.9858074753007731
# Bisection took 1.1814498901367188s
# Starting mutation...
# Finished mutation. Mutation took 0.8063957691192627s
# Mean accept rate: 0.41
# New iteration: p = 126
# Starting bisection...
# Updated temperature, new temperature is: 0.9761292090204768
# Bisection took 1.0208094120025635s
# Starting mutation...
# Finished mutation. Mutation took 0.7604730129241943s
# Mean accept rate: 0.29800000000000004
# New iteration: p = 127
# Starting bisection...
# Updated temperature, new temperature is: 0.9682625296509157
# Bisection took 1.2517294883728027s
# Starting mutation...
# Finished mutation. Mutation took 0.8236384391784668s
# Mean accept rate: 0.319
# New iteration: p = 128
# Starting bisection...
# Updated temperature, new temperature is: 0.9566746534493112
# Bisection took 1.2053232192993164s
# Starting mutation...
# Finished mutation. Mutation took 0.7610111236572266s
# Mean accept rate: 0.297
# New iteration: p = 129
# Starting bisection...
# Updated temperature, new temperature is: 0.9465016855432493
# Bisection took 1.1717336177825928s
# Starting mutation...
# Finished mutation. Mutation took 0.7929835319519043s
# Mean accept rate: 0.27699999999999997
# New iteration: p = 130
# Starting bisection...
# Updated temperature, new temperature is: 0.9386029534466303
# Bisection took 1.229339361190796s
# Starting mutation...
# Finished mutation. Mutation took 0.7384805679321289s
# Mean accept rate: 0.386
# New iteration: p = 131
# Starting bisection...
# Updated temperature, new temperature is: 0.9293751599677467
# Bisection took 1.1903369426727295s
# Starting mutation...
# Finished mutation. Mutation took 0.6870119571685791s
# Mean accept rate: 0.291
# New iteration: p = 132
# Starting bisection...
# Updated temperature, new temperature is: 0.9199935660616732
# Bisection took 1.2203245162963867s
# Starting mutation...
# Finished mutation. Mutation took 0.8221540451049805s
# Mean accept rate: 0.28500000000000003
# New iteration: p = 133
# Starting bisection...
# Updated temperature, new temperature is: 0.9108430875455196
# Bisection took 1.077319860458374s
# Starting mutation...
# Finished mutation. Mutation took 0.758242130279541s
# Mean accept rate: 0.225
# New iteration: p = 134
# Starting bisection...
# Updated temperature, new temperature is: 0.9005749938810221
# Bisection took 1.0897552967071533s
# Starting mutation...
# Finished mutation. Mutation took 0.9183251857757568s
# Mean accept rate: 0.331
# New iteration: p = 135
# Starting bisection...
# Updated temperature, new temperature is: 0.8900332526776652
# Bisection took 1.225992202758789s
# Starting mutation...
# Finished mutation. Mutation took 0.7353370189666748s
# Mean accept rate: 0.27599999999999997
# New iteration: p = 136
# Starting bisection...
# Updated temperature, new temperature is: 0.8792839451403045
# Bisection took 1.1265130043029785s
# Starting mutation...
# Finished mutation. Mutation took 0.7555921077728271s
# Mean accept rate: 0.31799999999999995
# New iteration: p = 137
# Starting bisection...
# Updated temperature, new temperature is: 0.8703637569520286
# Bisection took 1.1292171478271484s
# Starting mutation...
# Finished mutation. Mutation took 0.674574613571167s
# Mean accept rate: 0.32899999999999996
# New iteration: p = 138
# Starting bisection...
# Updated temperature, new temperature is: 0.8616171542745796
# Bisection took 1.265423059463501s
# Starting mutation...
# Finished mutation. Mutation took 0.8927733898162842s
# Mean accept rate: 0.268
# New iteration: p = 139
# Starting bisection...
# Updated temperature, new temperature is: 0.8512929076151688
# Bisection took 1.2501776218414307s
# Starting mutation...
# Finished mutation. Mutation took 0.8816087245941162s
# Mean accept rate: 0.30100000000000005
# New iteration: p = 140
# Starting bisection...
# Updated temperature, new temperature is: 0.8440271027795032
# Bisection took 1.0350077152252197s
# Starting mutation...
# Finished mutation. Mutation took 0.760493278503418s
# Mean accept rate: 0.29400000000000004
# New iteration: p = 141
# Starting bisection...
# Updated temperature, new temperature is: 0.8367445098601067
# Bisection took 1.202115774154663s
# Starting mutation...
# Finished mutation. Mutation took 0.7643001079559326s
# Mean accept rate: 0.3
# New iteration: p = 142
# Starting bisection...
# Updated temperature, new temperature is: 0.8270087909348667
# Bisection took 1.2517445087432861s
# Starting mutation...
# Finished mutation. Mutation took 0.7249691486358643s
# Mean accept rate: 0.316
# New iteration: p = 143
# Starting bisection...
# Updated temperature, new temperature is: 0.8158823818481149
# Bisection took 1.1452300548553467s
# Starting mutation...
# Finished mutation. Mutation took 0.8512251377105713s
# Mean accept rate: 0.30200000000000005
# New iteration: p = 144
# Starting bisection...
# Updated temperature, new temperature is: 0.8088363215942245
# Bisection took 1.0794556140899658s
# Starting mutation...
# Finished mutation. Mutation took 0.7786366939544678s
# Mean accept rate: 0.27899999999999997
# New iteration: p = 145
# Starting bisection...
# Updated temperature, new temperature is: 0.8017909206866094
# Bisection took 1.0217106342315674s
# Starting mutation...
# Finished mutation. Mutation took 0.8492813110351562s
# Mean accept rate: 0.33899999999999997
# New iteration: p = 146
# Starting bisection...
# Updated temperature, new temperature is: 0.7943274068735272
# Bisection took 1.2865450382232666s
# Starting mutation...
# Finished mutation. Mutation took 0.8582899570465088s
# Mean accept rate: 0.261
# New iteration: p = 147
# Starting bisection...
# Updated temperature, new temperature is: 0.7867891343911595
# Bisection took 1.2611258029937744s
# Starting mutation...
# Finished mutation. Mutation took 0.8343610763549805s
# Mean accept rate: 0.275
# New iteration: p = 148
# Starting bisection...
# Updated temperature, new temperature is: 0.7805308234939652
# Bisection took 0.8413681983947754s
# Starting mutation...
# Finished mutation. Mutation took 0.7717969417572021s
# Mean accept rate: 0.26300000000000007
# New iteration: p = 149
# Starting bisection...
# Updated temperature, new temperature is: 0.77334413273071
# Bisection took 1.2181658744812012s
# Starting mutation...
# Finished mutation. Mutation took 0.6711833477020264s
# Mean accept rate: 0.292
# New iteration: p = 150
# Starting bisection...
# Updated temperature, new temperature is: 0.7648209230577716
# Bisection took 1.1962828636169434s
# Starting mutation...
# Finished mutation. Mutation took 0.813194751739502s
# Mean accept rate: 0.28
# New iteration: p = 151
# Starting bisection...
# Updated temperature, new temperature is: 0.7559465712325761
# Bisection took 1.1273126602172852s
# Starting mutation...
# Finished mutation. Mutation took 0.7852623462677002s
# Mean accept rate: 0.268
# New iteration: p = 152
# Starting bisection...
# Updated temperature, new temperature is: 0.7473188322647677
# Bisection took 1.0335979461669922s
# Starting mutation...
# Finished mutation. Mutation took 0.708167314529419s
# Mean accept rate: 0.308
# New iteration: p = 153
# Starting bisection...
# Updated temperature, new temperature is: 0.7402956498758322
# Bisection took 1.1694014072418213s
# Starting mutation...
# Finished mutation. Mutation took 0.7960329055786133s
# Mean accept rate: 0.27899999999999997
# New iteration: p = 154
# Starting bisection...
# Updated temperature, new temperature is: 0.7327097617585688
# Bisection took 1.2027368545532227s
# Starting mutation...
# Finished mutation. Mutation took 0.9378824234008789s
# Mean accept rate: 0.331
# New iteration: p = 155
# Starting bisection...
# Updated temperature, new temperature is: 0.725867088919653
# Bisection took 1.1589467525482178s
# Starting mutation...
# Finished mutation. Mutation took 0.6782238483428955s
# Mean accept rate: 0.326
# New iteration: p = 156
# Starting bisection...
# Updated temperature, new temperature is: 0.7192284746726603
# Bisection took 1.182145595550537s
# Starting mutation...
# Finished mutation. Mutation took 0.8046422004699707s
# Mean accept rate: 0.33599999999999997
# New iteration: p = 157
# Starting bisection...
# Updated temperature, new temperature is: 0.7125580843364121
# Bisection took 1.2566146850585938s
# Starting mutation...
# Finished mutation. Mutation took 0.7108397483825684s
# Mean accept rate: 0.352
# New iteration: p = 158
# Starting bisection...
# Updated temperature, new temperature is: 0.7063350165880404
# Bisection took 1.1362876892089844s
# Starting mutation...
# Finished mutation. Mutation took 0.8083605766296387s
# Mean accept rate: 0.251
# New iteration: p = 159
# Starting bisection...
# Updated temperature, new temperature is: 0.6996517474621573
# Bisection took 1.0821223258972168s
# Starting mutation...
# Finished mutation. Mutation took 0.7705841064453125s
# Mean accept rate: 0.293
# New iteration: p = 160
# Starting bisection...
# Updated temperature, new temperature is: 0.6937442576896418
# Bisection took 1.2632560729980469s
# Starting mutation...
# Finished mutation. Mutation took 0.6986978054046631s
# Mean accept rate: 0.26499999999999996
# New iteration: p = 161
# Starting bisection...
# Updated temperature, new temperature is: 0.6867279916176159
# Bisection took 1.1458711624145508s
# Starting mutation...
# Finished mutation. Mutation took 0.7379229068756104s
# Mean accept rate: 0.269
# New iteration: p = 162
# Starting bisection...
# Updated temperature, new temperature is: 0.6815533499733384
# Bisection took 1.2616651058197021s
# Starting mutation...
# Finished mutation. Mutation took 0.8329908847808838s
# Mean accept rate: 0.313
# New iteration: p = 163
# Starting bisection...
# Updated temperature, new temperature is: 0.6758764616083903
# Bisection took 1.008683681488037s
# Starting mutation...
# Finished mutation. Mutation took 0.671461820602417s
# Mean accept rate: 0.284
# New iteration: p = 164
# Starting bisection...
# Updated temperature, new temperature is: 0.6692289751123073
# Bisection took 1.138505220413208s
# Starting mutation...
# Finished mutation. Mutation took 0.6707315444946289s
# Mean accept rate: 0.2879999999999999
# New iteration: p = 165
# Starting bisection...
# Updated temperature, new temperature is: 0.6632199585564034
# Bisection took 1.2027125358581543s
# Starting mutation...
# Finished mutation. Mutation took 0.6759517192840576s
# Mean accept rate: 0.28
# New iteration: p = 166
# Starting bisection...
# Updated temperature, new temperature is: 0.6577503776808873
# Bisection took 1.1458702087402344s
# Starting mutation...
# Finished mutation. Mutation took 0.68017578125s
# Mean accept rate: 0.326
# New iteration: p = 167
# Starting bisection...
# Updated temperature, new temperature is: 0.6521017366157531
# Bisection took 1.1073243618011475s
# Starting mutation...
# Finished mutation. Mutation took 0.6688001155853271s
# Mean accept rate: 0.254
# New iteration: p = 168
# Starting bisection...
# Updated temperature, new temperature is: 0.646882014628112
# Bisection took 1.1465306282043457s
# Starting mutation...
# Finished mutation. Mutation took 0.675590991973877s
# Mean accept rate: 0.265
# New iteration: p = 169
# Starting bisection...
# Updated temperature, new temperature is: 0.6411750907528317
# Bisection took 1.137495756149292s
# Starting mutation...
# Finished mutation. Mutation took 0.6820595264434814s
# Mean accept rate: 0.28300000000000003
# New iteration: p = 170
# Starting bisection...
# Updated temperature, new temperature is: 0.635391694726265
# Bisection took 1.0843849182128906s
# Starting mutation...
# Finished mutation. Mutation took 0.6676795482635498s
# Mean accept rate: 0.341
# New iteration: p = 171
# Starting bisection...
# Updated temperature, new temperature is: 0.629986936713866
# Bisection took 1.2159764766693115s
# Starting mutation...
# Finished mutation. Mutation took 0.654071569442749s
# Mean accept rate: 0.252
# New iteration: p = 172
# Starting bisection...
# Updated temperature, new temperature is: 0.6260396474477549
# Bisection took 1.1333205699920654s
# Starting mutation...
# Finished mutation. Mutation took 0.6696116924285889s
# Mean accept rate: 0.35999999999999993
# New iteration: p = 173
# Starting bisection...
# Updated temperature, new temperature is: 0.6207580117527214
# Bisection took 1.1924419403076172s
# Starting mutation...
# Finished mutation. Mutation took 0.6642756462097168s
# Mean accept rate: 0.307
# New iteration: p = 174
# Starting bisection...
# Updated temperature, new temperature is: 0.6156404810336705
# Bisection took 1.1852738857269287s
# Starting mutation...
# Finished mutation. Mutation took 0.6656110286712646s
# Mean accept rate: 0.272
# New iteration: p = 175
# Starting bisection...
# Updated temperature, new temperature is: 0.6075265842082989
# Bisection took 0.9735918045043945s
# Starting mutation...
# Finished mutation. Mutation took 0.6755795478820801s
# Mean accept rate: 0.30700000000000005
# New iteration: p = 176
# Starting bisection...
# Updated temperature, new temperature is: 0.6020948144551541
# Bisection took 1.1295902729034424s
# Starting mutation...
# Finished mutation. Mutation took 0.6650269031524658s
# Mean accept rate: 0.24600000000000002
# New iteration: p = 177
# Starting bisection...
# Updated temperature, new temperature is: 0.5974656857235187
# Bisection took 1.1805851459503174s
# Starting mutation...
# Finished mutation. Mutation took 0.6753268241882324s
# Mean accept rate: 0.245
# New iteration: p = 178
# Starting bisection...
# Updated temperature, new temperature is: 0.5918407663236238
# Bisection took 1.0877931118011475s
# Starting mutation...
# Finished mutation. Mutation took 0.6629166603088379s
# Mean accept rate: 0.23499999999999996
# New iteration: p = 179
# Starting bisection...
# Updated temperature, new temperature is: 0.5854728877584747
# Bisection took 1.14455246925354s
# Starting mutation...
# Finished mutation. Mutation took 0.6688089370727539s
# Mean accept rate: 0.322
# New iteration: p = 180
# Starting bisection...
# Updated temperature, new temperature is: 0.5804084348163558
# Bisection took 1.140394926071167s
# Starting mutation...
# Finished mutation. Mutation took 0.6742796897888184s
# Mean accept rate: 0.24599999999999997
# New iteration: p = 181
# Starting bisection...
# Updated temperature, new temperature is: 0.5752775789154121
# Bisection took 1.088855266571045s
# Starting mutation...
# Finished mutation. Mutation took 0.6725072860717773s
# Mean accept rate: 0.28500000000000003
# New iteration: p = 182
# Starting bisection...
# Updated temperature, new temperature is: 0.5700333045016461
# Bisection took 0.7559075355529785s
# Starting mutation...
# Finished mutation. Mutation took 0.6730403900146484s
# Mean accept rate: 0.316
# New iteration: p = 183
# Starting bisection...
# Updated temperature, new temperature is: 0.565541612825641
# Bisection took 1.1998353004455566s
# Starting mutation...
# Finished mutation. Mutation took 0.6719658374786377s
# Mean accept rate: 0.24500000000000002
# New iteration: p = 184
# Starting bisection...
# Updated temperature, new temperature is: 0.5607670032458063
# Bisection took 1.1272778511047363s
# Starting mutation...
# Finished mutation. Mutation took 0.6658117771148682s
# Mean accept rate: 0.293
# New iteration: p = 185
# Starting bisection...
# Updated temperature, new temperature is: 0.5554934696987979
# Bisection took 1.0760185718536377s
# Starting mutation...
# Finished mutation. Mutation took 0.6700019836425781s
# Mean accept rate: 0.29000000000000004
# New iteration: p = 186
# Starting bisection...
# Updated temperature, new temperature is: 0.5502163264525053
# Bisection took 0.9734897613525391s
# Starting mutation...
# Finished mutation. Mutation took 0.6691668033599854s
# Mean accept rate: 0.27899999999999997
# New iteration: p = 187
# Starting bisection...
# Updated temperature, new temperature is: 0.546119532106697
# Bisection took 1.031480073928833s
# Starting mutation...
# Finished mutation. Mutation took 0.6747264862060547s
# Mean accept rate: 0.236
# New iteration: p = 188
# Starting bisection...
# Updated temperature, new temperature is: 0.5426555868800058
# Bisection took 1.2476005554199219s
# Starting mutation...
# Finished mutation. Mutation took 0.6834559440612793s
# Mean accept rate: 0.22699999999999998
# New iteration: p = 189
# Starting bisection...
# Updated temperature, new temperature is: 0.5385114864258976
# Bisection took 1.188422679901123s
# Starting mutation...
# Finished mutation. Mutation took 0.6747338771820068s
# Mean accept rate: 0.306
# New iteration: p = 190
# Starting bisection...
# Updated temperature, new temperature is: 0.533608303690501
# Bisection took 0.7606527805328369s
# Starting mutation...
# Finished mutation. Mutation took 0.6725540161132812s
# Mean accept rate: 0.284
# New iteration: p = 191
# Starting bisection...
# Updated temperature, new temperature is: 0.5294437097528382
# Bisection took 1.1388623714447021s
# Starting mutation...
# Finished mutation. Mutation took 0.6665463447570801s
# Mean accept rate: 0.26
# New iteration: p = 192
# Starting bisection...
# Updated temperature, new temperature is: 0.5245543079209629
# Bisection took 1.192638874053955s
# Starting mutation...
# Finished mutation. Mutation took 0.6652133464813232s
# Mean accept rate: 0.28900000000000003
# New iteration: p = 193
# Starting bisection...
# Updated temperature, new temperature is: 0.5196000267884842
# Bisection took 1.0328454971313477s
# Starting mutation...
# Finished mutation. Mutation took 0.6685705184936523s
# Mean accept rate: 0.305
# New iteration: p = 194
# Starting bisection...
# Updated temperature, new temperature is: 0.5157208349952087
# Bisection took 1.194481611251831s
# Starting mutation...
# Finished mutation. Mutation took 0.6786479949951172s
# Mean accept rate: 0.23
# New iteration: p = 195
# Starting bisection...
# Updated temperature, new temperature is: 0.511580832126939
# Bisection took 1.0810673236846924s
# Starting mutation...
# Finished mutation. Mutation took 0.6641409397125244s
# Mean accept rate: 0.264
# New iteration: p = 196
# Starting bisection...
# Updated temperature, new temperature is: 0.507179103671174
# Bisection took 1.1898486614227295s
# Starting mutation...
# Finished mutation. Mutation took 0.6684284210205078s
# Mean accept rate: 0.285
# New iteration: p = 197
# Starting bisection...
# Updated temperature, new temperature is: 0.5033299787974381
# Bisection took 1.1864755153656006s
# Starting mutation...
# Finished mutation. Mutation took 0.6633446216583252s
# Mean accept rate: 0.337
# New iteration: p = 198
# Starting bisection...
# Updated temperature, new temperature is: 0.49881717175567386
# ...
# Mean accept rate: 0.263
# New iteration: p = 251
# Starting bisection...
# Updated temperature, new temperature is: 0.31967931566549945
# Bisection took 1.17899751663208s
# Starting mutation...
# Finished mutation. Mutation took 0.6706950664520264s
# Mean accept rate: 0.275
# New iteration: p = 252
# Starting bisection...
# Updated temperature, new temperature is: 0.31663029560884115
# Bisection took 1.1675772666931152s
# Starting mutation...
# Finished mutation. Mutation took 0.6669661998748779s
# Mean accept rate: 0.288
# New iteration: p = 253
# Starting bisection...
# Updated temperature, new temperature is: 0.3144505563973121
# Bisection took 1.26973295211792s
# Starting mutation...
# Finished mutation. Mutation took 0.6708920001983643s
# Mean accept rate: 0.287
# New iteration: p = 254
# Starting bisection...
# Updated temperature, new temperature is: 0.31188969871277195
# Bisection took 1.199486494064331s
# Starting mutation...
# Finished mutation. Mutation took 0.763401985168457s
# Mean accept rate: 0.2889999999999999
# New iteration: p = 255
# Starting bisection...
# Updated temperature, new temperature is: 0.3100062277874609
# Bisection took 1.2333827018737793s
# Starting mutation...
# Finished mutation. Mutation took 0.6754114627838135s
# Mean accept rate: 0.23099999999999998
# New iteration: p = 256
# Starting bisection...
# Updated temperature, new temperature is: 0.30795998169644223
# Bisection took 1.0675485134124756s
# Starting mutation...
# Finished mutation. Mutation took 0.7654235363006592s
# Mean accept rate: 0.29
# New iteration: p = 257
# Starting bisection...
# Updated temperature, new temperature is: 0.30471604787471956
# Bisection took 1.1365907192230225s
# Starting mutation...
# Finished mutation. Mutation took 0.72232985496521s
# Mean accept rate: 0.28
# New iteration: p = 258
# Starting bisection...
# Updated temperature, new temperature is: 0.3029965036729664
# Bisection took 1.3776812553405762s
# Starting mutation...
# Finished mutation. Mutation took 0.7694826126098633s
# Mean accept rate: 0.254
# New iteration: p = 259
# Starting bisection...
# Updated temperature, new temperature is: 0.30131689057522404
# Bisection took 1.329667329788208s
# Starting mutation...
# Finished mutation. Mutation took 0.6816380023956299s
# Mean accept rate: 0.301
# New iteration: p = 260
# Starting bisection...
# Updated temperature, new temperature is: 0.2988753957914648
# Bisection took 1.199192762374878s
# Starting mutation...
# Finished mutation. Mutation took 0.7267279624938965s
# Mean accept rate: 0.25299999999999995
# New iteration: p = 261
# Starting bisection...
# Updated temperature, new temperature is: 0.29573036718280377
# Bisection took 1.1521034240722656s
# Starting mutation...
# Finished mutation. Mutation took 0.8140466213226318s
# Mean accept rate: 0.24299999999999994
# New iteration: p = 262
# Starting bisection...
# Updated temperature, new temperature is: 0.2941163869230765
# Bisection took 1.2728345394134521s
# Starting mutation...
# Finished mutation. Mutation took 0.7371828556060791s
# Mean accept rate: 0.22999999999999995
# New iteration: p = 263
# Starting bisection...
# Updated temperature, new temperature is: 0.2923183328539184
# Bisection took 1.1833293437957764s
# Starting mutation...
# Finished mutation. Mutation took 0.8488245010375977s
# Mean accept rate: 0.269
# New iteration: p = 264
# Starting bisection...
# Updated temperature, new temperature is: 0.29023334028340303
# Bisection took 0.9781680107116699s
# Starting mutation...
# Finished mutation. Mutation took 0.7253537178039551s
# Mean accept rate: 0.3
# New iteration: p = 265
# Starting bisection...
# Updated temperature, new temperature is: 0.28830645812756184
# Bisection took 1.2744553089141846s
# Starting mutation...
# Finished mutation. Mutation took 0.8607373237609863s
# Mean accept rate: 0.27099999999999996
# New iteration: p = 266
# Starting bisection...
# Updated temperature, new temperature is: 0.2865104034761592
# Bisection took 1.3075613975524902s
# Starting mutation...
# Finished mutation. Mutation took 0.8340752124786377s
# Mean accept rate: 0.29200000000000004
# New iteration: p = 267
# Starting bisection...
# Updated temperature, new temperature is: 0.28411599957642897
# Bisection took 1.1563634872436523s
# Starting mutation...
# Finished mutation. Mutation took 0.7810108661651611s
# Mean accept rate: 0.28400000000000003
# New iteration: p = 268
# Starting bisection...
# Updated temperature, new temperature is: 0.2816654729765168
# Bisection took 1.247976303100586s
# Starting mutation...
# Finished mutation. Mutation took 0.8753995895385742s
# Mean accept rate: 0.28300000000000003
# New iteration: p = 269
# Starting bisection...
# Updated temperature, new temperature is: 0.279453962816712
# Bisection took 1.1335947513580322s
# Starting mutation...
# Finished mutation. Mutation took 0.7159152030944824s
# Mean accept rate: 0.26
# New iteration: p = 270
# Starting bisection...
# Updated temperature, new temperature is: 0.27713813724669684
# Bisection took 1.2410717010498047s
# Starting mutation...
# Finished mutation. Mutation took 0.8597919940948486s
# Mean accept rate: 0.21099999999999997
# New iteration: p = 271
# Starting bisection...
# Updated temperature, new temperature is: 0.2742603368790185
# Bisection took 1.0311150550842285s
# Starting mutation...
# Finished mutation. Mutation took 0.8164024353027344s
# Mean accept rate: 0.28300000000000003
# New iteration: p = 272
# Starting bisection...
# Updated temperature, new temperature is: 0.271721000527249
# Bisection took 1.178292989730835s
# Starting mutation...
# Finished mutation. Mutation took 0.8022034168243408s
# Mean accept rate: 0.26999999999999996
# New iteration: p = 273
# Starting bisection...
# Updated temperature, new temperature is: 0.26980509705430367
# Bisection took 1.2228984832763672s
# Starting mutation...
# Finished mutation. Mutation took 0.7935929298400879s
# Mean accept rate: 0.314
# New iteration: p = 274
# Starting bisection...
# Updated temperature, new temperature is: 0.26777090988349694
# Bisection took 1.2345211505889893s
# Starting mutation...
# Finished mutation. Mutation took 0.7076072692871094s
# Mean accept rate: 0.267
# New iteration: p = 275
# Starting bisection...
# Updated temperature, new temperature is: 0.26557516082279037
# Bisection took 1.1821813583374023s
# Starting mutation...
# Finished mutation. Mutation took 0.8256990909576416s
# Mean accept rate: 0.29600000000000004
# New iteration: p = 276
# Starting bisection...
# Updated temperature, new temperature is: 0.2633366942958085
# Bisection took 1.048290729522705s
# Starting mutation...
# Finished mutation. Mutation took 0.8657596111297607s
# Mean accept rate: 0.276
# New iteration: p = 277
# Starting bisection...
# Updated temperature, new temperature is: 0.26122075537612827
# Bisection took 1.2712535858154297s
# Starting mutation...
# Finished mutation. Mutation took 0.8241970539093018s
# Mean accept rate: 0.29399999999999993
# New iteration: p = 278
# Starting bisection...
# Updated temperature, new temperature is: 0.2594665302452231
# Bisection took 1.2654659748077393s
# Starting mutation...
# Finished mutation. Mutation took 0.8040561676025391s
# Mean accept rate: 0.2830000000000001
# New iteration: p = 279
# Starting bisection...
# Updated temperature, new temperature is: 0.2572739533192397
# Bisection took 0.7418649196624756s
# Starting mutation...
# Finished mutation. Mutation took 0.7227606773376465s
# Mean accept rate: 0.251
# New iteration: p = 280
# Starting bisection...
# Updated temperature, new temperature is: 0.25542419050773524
# Bisection took 1.2212190628051758s
# Starting mutation...
# Finished mutation. Mutation took 0.8567712306976318s
# Mean accept rate: 0.26499999999999996
# New iteration: p = 281
# Starting bisection...
# Updated temperature, new temperature is: 0.25341787321549103
# Bisection took 1.2040038108825684s
# Starting mutation...
# Finished mutation. Mutation took 0.699702262878418s
# Mean accept rate: 0.271
# New iteration: p = 282
# Starting bisection...
# Updated temperature, new temperature is: 0.2522088809405331
# Bisection took 1.1205155849456787s
# Starting mutation...
# Finished mutation. Mutation took 0.7132408618927002s
# Mean accept rate: 0.259
# New iteration: p = 283
# Starting bisection...
# Updated temperature, new temperature is: 0.2508735370639641
# Bisection took 1.4110307693481445s
# Starting mutation...
# Finished mutation. Mutation took 0.8938355445861816s
# Mean accept rate: 0.243
# New iteration: p = 284
# Starting bisection...
# Updated temperature, new temperature is: 0.24929585509093088
# Bisection took 1.1896982192993164s
# Starting mutation...
# Finished mutation. Mutation took 0.7579550743103027s
# Mean accept rate: 0.23600000000000002
# New iteration: p = 285
# Starting bisection...
# Updated temperature, new temperature is: 0.2471178158825303
# Bisection took 1.1708438396453857s
# Starting mutation...
# Finished mutation. Mutation took 0.7866981029510498s
# Mean accept rate: 0.26
# New iteration: p = 286
# Starting bisection...
# Updated temperature, new temperature is: 0.2449188969280227
# Bisection took 1.1901538372039795s
# Starting mutation...
# Finished mutation. Mutation took 0.7540245056152344s
# Mean accept rate: 0.196
# New iteration: p = 287
# Starting bisection...
# Updated temperature, new temperature is: 0.24328164097447239
# Bisection took 1.2104969024658203s
# Starting mutation...
# Finished mutation. Mutation took 0.770615816116333s
# Mean accept rate: 0.259
# New iteration: p = 288
# Starting bisection...
# Updated temperature, new temperature is: 0.24136123928218528
# Bisection took 1.2646079063415527s
# Starting mutation...
# Finished mutation. Mutation took 0.8513102531433105s
# Mean accept rate: 0.22699999999999998
# New iteration: p = 289
# Starting bisection...
# Updated temperature, new temperature is: 0.23936485895970488
# Bisection took 1.1551637649536133s
# Starting mutation...
# Finished mutation. Mutation took 0.8045592308044434s
# Mean accept rate: 0.31099999999999994
# New iteration: p = 290
# Starting bisection...
# Updated temperature, new temperature is: 0.2372964594289861
# Bisection took 1.1053447723388672s
# Starting mutation...
# Finished mutation. Mutation took 0.8700048923492432s
# Mean accept rate: 0.24900000000000003
# New iteration: p = 291
# Starting bisection...
# Updated temperature, new temperature is: 0.23547301714467228
# Bisection took 1.259681224822998s
# Starting mutation...
# Finished mutation. Mutation took 0.7930777072906494s
# Mean accept rate: 0.29400000000000004
# New iteration: p = 292
# Starting bisection...
# Updated temperature, new temperature is: 0.23342982274683305
# Bisection took 1.257462501525879s
# Starting mutation...
# Finished mutation. Mutation took 0.7714488506317139s
# Mean accept rate: 0.281
# New iteration: p = 293
# Starting bisection...
# Updated temperature, new temperature is: 0.23188116251455235
# Bisection took 1.1785054206848145s
# Starting mutation...
# Finished mutation. Mutation took 0.6633191108703613s
# Mean accept rate: 0.247
# New iteration: p = 294
# Starting bisection...
# Updated temperature, new temperature is: 0.23021796791791424
# Bisection took 1.1529004573822021s
# Starting mutation...
# Finished mutation. Mutation took 0.6638567447662354s
# Mean accept rate: 0.23199999999999998
# New iteration: p = 295
# Starting bisection...
# Updated temperature, new temperature is: 0.22850213540039585
# Bisection took 1.2131659984588623s
# Starting mutation...
# Finished mutation. Mutation took 0.6744418144226074s
# Mean accept rate: 0.25899999999999995
# New iteration: p = 296
# Starting bisection...
# Updated temperature, new temperature is: 0.22691886511309933
# Bisection took 1.1999380588531494s
# Starting mutation...
# Finished mutation. Mutation took 0.6551651954650879s
# Mean accept rate: 0.25299999999999995
# New iteration: p = 297
# Starting bisection...
# Updated temperature, new temperature is: 0.22516212549428255
# Bisection took 1.1376008987426758s
# Starting mutation...
# Finished mutation. Mutation took 0.663548469543457s
# Mean accept rate: 0.206
# New iteration: p = 298
# Starting bisection...
# Updated temperature, new temperature is: 0.2233436910115838
# Bisection took 1.1924281120300293s
# Starting mutation...
# Finished mutation. Mutation took 0.6762115955352783s
# Mean accept rate: 0.277
# New iteration: p = 299
# Starting bisection...
# Updated temperature, new temperature is: 0.2213595452036071
# Bisection took 1.0904221534729004s
# Starting mutation...
# Finished mutation. Mutation took 0.679898738861084s
# Mean accept rate: 0.27699999999999997
# New iteration: p = 300
# Starting bisection...
# Updated temperature, new temperature is: 0.21964863457844663
# Bisection took 1.155364751815796s
# Starting mutation...
# Finished mutation. Mutation took 0.8208837509155273s
# Mean accept rate: 0.195
# New iteration: p = 301
# Starting bisection...
# Updated temperature, new temperature is: 0.21750931383298863
# Bisection took 1.187269687652588s
# Starting mutation...
# Finished mutation. Mutation took 0.9091005325317383s
# Mean accept rate: 0.17800000000000005
# New iteration: p = 302
# Starting bisection...
# Updated temperature, new temperature is: 0.21579078233758373
# Bisection took 1.1946299076080322s
# Starting mutation...
# Finished mutation. Mutation took 0.6647179126739502s
# Mean accept rate: 0.207
# New iteration: p = 303
# Starting bisection...
# Updated temperature, new temperature is: 0.21432081453390667
# Bisection took 1.2476613521575928s
# Starting mutation...
# Finished mutation. Mutation took 0.7388594150543213s
# Mean accept rate: 0.254
# New iteration: p = 304
# Starting bisection...
# Updated temperature, new temperature is: 0.2126984475316013
# Bisection took 1.239912748336792s
# Starting mutation...
# Finished mutation. Mutation took 0.758918285369873s
# Mean accept rate: 0.19399999999999998
# New iteration: p = 305
# Starting bisection...
# Updated temperature, new temperature is: 0.2112525014222717
# Bisection took 1.1742422580718994s
# Starting mutation...
# Finished mutation. Mutation took 0.7741594314575195s
# Mean accept rate: 0.24100000000000002
# New iteration: p = 306
# Starting bisection...
# Updated temperature, new temperature is: 0.2095381885420382
# Bisection took 1.1977834701538086s
# Starting mutation...
# Finished mutation. Mutation took 0.8796274662017822s
# Mean accept rate: 0.23200000000000004
# New iteration: p = 307
# Starting bisection...
# Updated temperature, new temperature is: 0.20823657453444355
# Bisection took 1.1301743984222412s
# Starting mutation...
# Finished mutation. Mutation took 0.7933664321899414s
# Mean accept rate: 0.21399999999999994
# New iteration: p = 308
# Starting bisection...
# Updated temperature, new temperature is: 0.2065358525796097
# Bisection took 1.243314266204834s
# Starting mutation...
# Finished mutation. Mutation took 0.8106653690338135s
# Mean accept rate: 0.21100000000000002
# New iteration: p = 309
# Starting bisection...
# Updated temperature, new temperature is: 0.20526956742714791
# Bisection took 1.182788372039795s
# Starting mutation...
# Finished mutation. Mutation took 0.8056464195251465s
# Mean accept rate: 0.221
# New iteration: p = 310
# Starting bisection...
# Updated temperature, new temperature is: 0.20369486090881833
# Bisection took 1.138477087020874s
# Starting mutation...
# Finished mutation. Mutation took 0.7793538570404053s
# Mean accept rate: 0.21200000000000002
# New iteration: p = 311
# Starting bisection...
# Updated temperature, new temperature is: 0.2019736230453269
# Bisection took 1.2817134857177734s
# Starting mutation...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[152], line 11
#       7
#       8 # Sample observations from true state-space model
#       9 ys = sample_state_space_model(T=T,us=us,rng=rng)
#      10
# ---> 11 samples, records = smc_sampler(
#      12     ys=ys,
#      13     us=us,
#      14     initial_mh_iters=300,
#
# Cell In[151], line 456, in smc_sampler(ys, us, initial_mh_iters, initial_mh_sd, mh_iters, mh_sd, n_sample_particles, n_filter_particles, temp, min_temp, alpha, max_smc_iters, verbose, alternative_tempering, adaptive_pmh)
#     452             print(f'Starting mutation...')
#     453             t0 = time.time()
#     454
#     455         # This one line replaces the entire mutation loop/pool logic
# --> 456         mean_accept_rate = run_parallel_mutation(
#     457                                             thetas=thetas,
#     458                                             xss=xss,
#     459                                             aass=aass,
#
# KeyboardInterrupt:

# %%
# Plot result
plt.scatter(samples[:,0],samples[:,1],label=r'SMC sample')
plt.xlim(0,2)
plt.ylim(0,2)
plt.xlabel(r'$\theta_1$')
plt.ylabel(r'$\theta_2$')
plt.legend()

print(np.mean(samples,axis=0))

# print(np.mean([x['particles'] for x in records.values()], axis=1))
# Out:
# [1.05303894 0.96581547]

# %%
""" Given SMC sampler particle history, draw a gif animation of the particle
evolution. Used AI for this one.
"""

# FIX: Safely check for the style string directly inside the list object
if 'seaborn-v0_8-whitegrid' in plt.style.available:
    plt.style.use('seaborn-v0_8-whitegrid')
else:
    plt.style.use('default')

fig, ax = plt.subplots(figsize=(8, 6), dpi=120)

# --- 1. Prepare your data ---
# Renamed to `record` per your instruction!
# Expected structure: { p: {'temp': float, 'particles': ndarray(N, 2)} }
iterations = sorted(list(records.keys()))

# Set absolute boundaries based on global mins and maxes of all particles
all_particles = np.vstack([records[p]['particles'] for p in iterations])
x_min, x_max = all_particles[:, 0].min() - 0.2, all_particles[:, 0].max() + 0.2
y_min, y_max = all_particles[:, 1].min() - 0.2, all_particles[:, 1].max() + 0.2


# --- 2. Initialize the plot elements ---
scatter = ax.scatter([], [], c='#1f77b4', alpha=0.5, s=15, edgecolors='none', label='Particles', zorder=3)

# FIX: Removed the trailing comma here because ax.add_line returns a single object
mean_dot = ax.add_line(plt.Line2D([], [], color='#d62728', marker='o', markersize=8, ls='', label='Empirical Mean', zorder=4))

title_text = ax.set_title('', fontsize=12, fontweight='bold', pad=10)

ax.set_xlim(x_min, x_max)
ax.set_ylim(y_min, y_max)
ax.set_xlabel(r'$\theta_1$', fontsize=11)
ax.set_ylabel(r'$\theta_2$', fontsize=11)
ax.legend(loc='upper right', frameon=True, facecolor='white', edgecolor='none')

# Global list container to clear previous contour paths on every frame cycle
kde_container = []

# --- 3. Define the frame update function ---
def update(frame_idx):
    p = iterations[frame_idx]
    data = records[p] # Using the updated naming layout
    particles = data['particles']
    temp = data['temp']
    
    # Wipe the old KDE paths out of the scene to prevent overlay buildup
    for coll in kde_container:
        coll.remove()
    kde_container.clear()
    
    # A. Redraw particle coordinates
    scatter.set_offsets(particles)
    
    # B. Track center mass location
    p_mean = np.mean(particles, axis=0)
    mean_dot.set_data([p_mean[0]], [p_mean[1]])
    
    # C. Morph the continuous contour landscape
    try:
        kde = sns.kdeplot(
            x=particles[:, 0], y=particles[:, 1],
            ax=ax, cmap="Blues", fill=True, alpha=0.35, 
            thresh=0.05, levels=10, zorder=1
        )
        for coll in kde.collections:
            kde_container.append(coll)
    except np.linalg.LinAlgError:
        pass 
        
    title_text.set_text(f"SMC Iteration: {p}  |  Temperature ($\lambda_p$): {temp:.4f}")
    return scatter, mean_dot, title_text

# --- 4. Compile the Animation ---
anim = FuncAnimation(
    fig, update, 
    frames=len(iterations), 
    interval=250,  
    blit=False     
)

# To export this frame loop directly into a working file:
anim.save('results/particle_filter_morphing_adaptive.gif', writer='pillow', fps=4)

plt.close()
# Out:
# <>:72: SyntaxWarning: invalid escape sequence '\l'
# <>:72: SyntaxWarning: invalid escape sequence '\l'
# /tmp/ipykernel_60292/3368319860.py:72: SyntaxWarning: invalid escape sequence '\l'
#   title_text.set_text(f"SMC Iteration: {p}  |  Temperature ($\lambda_p$): {temp:.4f}")

# %%
""" Save the latest record """

df = pd.DataFrame.from_dict(records, orient="index")
df.to_csv("results/smc_records_thisone.csv")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 3
#       1 """ Save the latest record """
#       2
# ----> 3 df = pd.DataFrame.from_dict(records, orient="index")
#       4 df.to_csv("results/smc_records_thisone.csv")
#
# NameError: name 'records' is not defined

# %%
""" Load a record """

df = pd.read_csv('results/smc_records_thisone.csv')

# For some reason, 'particles' column contains strings
# So quick fix here
def parse_particles(s):
    """
    Converts a string like:
    '[[1.1 0.7]\n [1.3 0.6]]'
    into a (N, 2) float array.
    """
    # split rows
    rows = s.strip().split("\n")

    # convert each row into floats
    data = []
    for r in rows:
        r = r.strip().replace("[", "").replace("]", "")
        if len(r) == 0:
            continue
        data.append([float(x) for x in r.split()])

    return np.array(data, dtype=np.float64)

df["particles"] = df["particles"].apply(parse_particles)

df.head()
# Out:
#    Unnamed: 0       temp                                          particles  \
# 0           0  10.000000  [[1.30980055, 0.5685367], [1.33292977, 0.55907...
# 1           1   9.545895  [[0.81960175, 1.74155131], [0.98621521, 1.1690...
# 2           2   9.158849  [[0.79808024, 1.2413223], [0.81659799, 1.34561...
# 3           3   8.779136  [[0.62002529, 1.43198331], [0.97958169, 1.1585...
# 4           4   8.457198  [[0.73191502, 1.14939582], [0.79807447, 1.1543...
#
#                                      log_likelihoods  accept_rate
# 0  [-428.3449691  -427.83340351 -427.79869225 -42...     0.706667
# 1  [-425.71619638 -424.11718767 -423.78089196 -42...     0.934000
# 2  [-419.91193274 -419.91972883 -419.83267964 -41...     0.940000
# 3  [-416.69713686 -416.42762483 -416.83332254 -41...     0.920000
# 4  [-413.46974753 -413.00957569 -414.25714566 -41...     0.930000

# %%
# Final particle population

link_blue = (120/255, 120/255, 149/255)

particles = np.asarray(df.iloc[-1]["particles"])
theta1 = particles[:, 0]
theta2 = particles[:, 1]

fig, axs = plt.subplots(2, 1, figsize=(7, 6), sharex=False)

for ax, theta, name in zip(
    axs,
    [theta1, theta2],
    [r"$\theta_1$", r"$\theta_2$"]
):
    ax.hist(
        theta,
        bins=25,
        density=True,
        color=link_blue,
        alpha=0.75,
        edgecolor="black",
        linewidth=0.5,
    )

    ax.axvline(
        1.0,
        color="crimson",
        linestyle="--",
        linewidth=2,
        label="True value"
    )

    ax.set_title(name, fontsize=16, pad=10)
    ax.set_ylabel("Density")
    ax.grid(alpha=0.25)

    # prettier box
    for spine in ax.spines.values():
        spine.set_linewidth(1.2)

    ax.legend(frameon=True)

fig.suptitle(
    "Posterior approximation by final SMC sample",
    fontsize=14,
    y=0.98
)

plt.tight_layout()
plt.show()

# %%
""" Visualize PMMH acceptance rates over iterations """

accept_rates = df['accept_rate']

plt.xlabel('SMC iteration')
plt.ylabel('Mean PMMH acccept rate')
plt.plot(accept_rates[1:])
plt.show()

# %%
""" Piece of code for estimating the variance of
a particle filter likelihood estimate at a given parameter value
"""

@njit(parallel=True)
def estimate_log_marginal_variance_parallel(temp, n_particles, ys, us, thetas, n_repeats):
    n_samples = thetas.shape[0]

    # log marginal likelihood estimate for each repeat
    log_marginals = np.empty(n_repeats, dtype=np.float64)

    for r in prange(n_repeats):
        log_liks = np.empty(n_samples, dtype=np.float64)

        for m in range(n_samples):
            _, _, log_lik = particle_filter(temp, n_particles, ys, us, thetas[m])
            log_liks[m] = log_lik

        max_log_lik = np.max(log_liks)
        log_marginals[r] = max_log_lik + np.log(np.mean(np.exp(log_liks - max_log_lik)))

    return np.mean(log_marginals), np.var(log_marginals), np.std(log_marginals)

# %%
T = 200 # Number of observations
                              
# Exogenous input variables
rng = np.random.default_rng(seed=42) # Want to fix this while keeping the rest random
us = rng.normal(loc=0, scale=1, size=T)

# Sample observations from true state-space model
ys = sample_state_space_model(T=T,us=us,rng=rng)

n_particles = len(df["particles"].iloc[0]) # Number of particles

# Loop over temperatures and particles
iter_delay = 5
temps_evaluated = []
means_of_vars = []
stds_of_vars = []
particle_means = []
for temp, particles in zip(df["temp"][::iter_delay],df["particles"][::iter_delay]):
    print(f"Computing variances; temp={temp}")

    mean_log_marginal, var_log_marginal, std_log_marginal = estimate_log_marginal_variance_parallel(
    temp, n_particles, ys, us, particles, n_repeats=15)

    temps_evaluated.append(temp)
    means_of_vars.append(var_log_marginal)
    stds_of_vars.append(std_log_marginal)    
    particle_means.append(np.mean(particles,axis=0))

    print(f"Mean of variances: {var_log_marginal}")

# Convert to numpy
temps_evaluated = np.array(temps_evaluated)
means_of_vars = np.array(means_of_vars)
stds_of_vars = np.array(stds_of_vars)
particle_means = np.array(particle_means)
# Out:
# Computing variances; temp=10.0
# Mean of variances: 0.01877628553846635
# Computing variances; temp=8.089205178129042
# Mean of variances: 0.02693597259782222
# Computing variances; temp=6.584221830276414
# Mean of variances: 0.03673975685661681
# Computing variances; temp=5.535461947870831
# Mean of variances: 0.05317904583839174
# Computing variances; temp=4.760250521213651
# Mean of variances: 0.067011850670646
# Computing variances; temp=4.200541570153542
# Mean of variances: 0.0781293356649771
# Computing variances; temp=3.7013549942757846
# Mean of variances: 0.09332157366430976
# Computing variances; temp=3.2985890273620218
# Mean of variances: 0.12749499561396826
# Computing variances; temp=2.9981783054227207
# Mean of variances: 0.13568800136263262
# Computing variances; temp=2.7451987427107967
# Mean of variances: 0.16008077405107557
# Computing variances; temp=2.529275828645687
# Mean of variances: 0.1771051159760378
# Computing variances; temp=2.3321014859532694
# Mean of variances: 0.1979178299403442
# Computing variances; temp=2.163988943508321
# Mean of variances: 0.21097265444908458
# Computing variances; temp=2.003421765846217
# Mean of variances: 0.22852968538191532
# Computing variances; temp=1.859928372419982
# Mean of variances: 0.2773364727705678
# Computing variances; temp=1.7278132145510243
# Mean of variances: 0.30481763581481297
# Computing variances; temp=1.6092307008571554
# Mean of variances: 0.3312140027778851
# Computing variances; temp=1.5135655463754245
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[35], line 21
#      17 particle_means = []
#      18 for temp, particles in zip(df["temp"][::iter_delay],df["particles"][::iter_delay]):
#      19     print(f"Computing variances; temp={temp}")
#      20
# ---> 21     mean_var, std_var = estimate_variances_parallel(temp, n_particles, ys, us, particles, n_repeats=15)
#      22
#      23     temps_evaluated.append(temp)
#      24     means_of_vars.append(mean_var)
#
# KeyboardInterrupt:

# %%
""" Plot mean of likelihood estimate variance
against temperature
"""

plt.figure(figsize=(6, 6)) 
plt.plot(
    temps_evaluated,
    means_of_vars,
    marker="x",
    color=(120/255, 120/255, 139/255),  # RGB {250,235,217}
    label='variance'
)

# plt.yscale('log')
plt.xscale('log')
plt.xlabel("Log temperature")
plt.gca().invert_xaxis() 
plt.ylabel("Variance")
plt.title("Variance of particle filter log-likelihood estimates")
plt.grid(True, which="both", ls="-", alpha=0.5)
plt.legend(loc='upper left')
plt.show()

# --- Style Configuration ---
# plt.rcParams["font.family"] = "sans-serif"
# plt.rcParams["axes.edgecolor"] = "#CCCCCC"
# plt.rcParams["axes.linewidth"] = 0.8

# # Initialize the figure
# fig, ax = plt.subplots(figsize=(7, 6.5), dpi=100)

# # --- Data Plotting ---
# # Using a clean, modern deep slate/indigo color (#5A5B7A) 
# # and slightly larger markers with line styling for elegance
# ax.plot(
#     temps_evaluated,
#     means_of_vars,
#     marker="x",
#     markersize=6,
#     mew=1.5,
#     color="#5A5B7A",
#     linewidth=1.75,
#     label="Variance",
# )

# # --- Axes & Scaling ---
# ax.set_xscale("log")
# ax.invert_xaxis()

# # --- Labels & Titles ---
# ax.set_xlabel("Temperature (Log Scale)", fontsize=11, labelpad=10, fontweight="medium")
# ax.set_ylabel("Variance", fontsize=11, labelpad=10, fontweight="medium")
# ax.set_title(
#     "Variance of Particle Filter Log-Likelihood Estimates",
#     fontsize=13,
#     fontweight="bold",
#     pad=15,
#     loc="left",  # Left-aligned titles look clean and modern
# )

# # --- Grid & Spines Clean-up ---
# # Subtle, light-gray grid lines that don't overwhelm the data
# ax.grid(True, which="both", linestyle="--", linewidth=0.5, color="#E2E8F0", alpha=0.7)

# # Despine: Remove the top and right borders
# ax.spines["top"].set_visible(False)
# ax.spines["right"].set_visible(False)
# ax.spines["left"].set_color("#CCCCCC")
# ax.spines["bottom"].set_color("#CCCCCC")

# # --- Legend & Layout ---
# # Clean legend without a harsh border box
# ax.legend(loc="upper left", frameon=False, fontsize=10)

# # Ensure everything fits beautifully without clipping
# plt.tight_layout()
# plt.show()

# %%
""" Plot RMSE between true parameters and particle means
against temperature
"""

particle_means = np.asarray(particle_means)

true_param = np.array([1,1])
rmses = np.sqrt(np.sum((particle_means - true_param)**2, axis=1))

plt.figure(figsize=(6, 6)) 
plt.plot(temps_evaluated, rmses, marker='x', color=(120/255, 120/255, 149/255), label='RMSE')
plt.xlabel("Log temperature")
plt.xscale('log')
plt.gca().invert_xaxis() 
plt.ylabel("RMSE")
plt.title("RMSE between particle mean and true parameter")
plt.grid(True, which="both", ls="-", alpha=0.5)
plt.legend(loc='upper right')
plt.show()
